# %% [markdown]
# ## Planner Agent

# %%
from src.agents.legal_contract_expert import LegalContractExpert
from src.utils import load_json, save_json
from src.cuad_executor import CUADExecutor
from src.cuad_evaluator import CUADEvaluator
from src.agents.planner import Planner

# %%
# Load CUAD dataset and select a file for testing the planner agent
data_path = 'data/processed/cuad_data.json'
cuad_data = load_json(data_path)
file_name = 'SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt'
file_path = '/Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt'
gpt_output_file_path = '/Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/gpt-4o/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.json'
o1_output_file_path = '/Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.json'

# %%
# Gpt-4o Planner Agent
gpt_planner = Planner(
    model='gpt-4o',
    temp = 0.7
)

gpt_plan = gpt_planner.process_contract(file_path)

# %%
gpt_planner.save_plan(gpt_output_file_path)
# Out:
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/gpt-4o/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.json

# %%
# o1-preview Planner Agent
o1_planner = Planner(
    model='o1',
)

o1_plan = o1_planner.process_contract(file_path)
# Out:
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt
# Generating plan...
# Error parsing assistant's response: unknown extension ?R at position 12

# %%
import json
print(json.dumps(o1_plan, indent=4))
# Out:
# {
#     "introduction": "This template serves as a comprehensive guide for extracting all essential information from this contract to enable a deep understanding of its clauses and terms. Agents should use this template to collect data systematically, ensuring that all relevant aspects are covered. This collected information will allow for accurate analysis and enable lawyers to answer a range of yes/no questions about clauses such as Non-Compete, No Solicitation, Revenue and Profit Sharing, Price Restrictions, Minimum Commitments, Volume Restrictions, Most Favored Nation clauses, Intellectual Property Ownership, Liability (including any caps or uncapped liability terms), Liquidated Damages, and Termination Conditions.",
#     "sections": [
#         {
#             "section_name": "Non-Compete Clause",
#             "section_description": "Information related to any non-compete clauses within the contract.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of Non-Compete Clause",
#                     "data_point_description": "Indicates whether a non-compete clause exists in the contract.",
#                     "data_point_questions": [
#                         "Does the contract contain any non-compete clause restricting one party from engaging in business activities that compete with the other party?"
#                     ],
#                     "data_point_instructions": "Review the entire contract to identify any clauses that restrict a party from engaging in competing business activities. Note the presence or absence of such clauses and provide the relevant contract section if present."
#                 },
#                 {
#                     "data_point_name": "Non-Compete Scope and Duration",
#                     "data_point_description": "Details about the scope and duration of the non-compete clause, including restricted activities and time frame.",
#                     "data_point_questions": [
#                         "What specific activities or businesses are restricted under the non-compete clause?",
#                         "What is the duration (in months or years) of the non-compete restriction?",
#                         "Is there a specific geographic area where the non-compete restrictions apply?"
#                     ],
#                     "data_point_instructions": "Extract and list all activities that are prohibited for the restricted party according to the non-compete clause, specify the duration of the restriction, and any geographic limitations outlined in the contract."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "NonCompeteAgent",
#                 "agent_instructions": "As the NonCompeteAgent, your role is to identify and extract all information related to non-compete clauses within the contract. Focus on determining whether such a clause exists and, if so, detailing its scope, duration, and geographic limitations. Carefully analyze the language used to understand any exceptions or special conditions. Use precise language and cite the relevant sections or clauses in the contract where this information is found."
#             }
#         },
#         {
#             "section_name": "No Solicitation Clause",
#             "section_description": "Information regarding any no-solicitation clauses that prevent parties from soliciting employees or clients.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of No Solicitation Clause",
#                     "data_point_description": "Indicates whether the contract includes any no-solicitation clauses.",
#                     "data_point_questions": [
#                         "Does the contract contain a no-solicitation clause?",
#                         "Are there any clauses that forbid one party from soliciting employees, customers, or clients of the other party?"
#                     ],
#                     "data_point_instructions": "Examine the contract to identify any clauses that restrict a party from soliciting employees, customers, or clients of the other party. Document if such a clause exists and note the relevant contract section."
#                 },
#                 {
#                     "data_point_name": "No-Solicitation Scope and Duration",
#                     "data_point_description": "Details about the scope and duration of the no-solicitation clause, such as who is protected and for how long.",
#                     "data_point_questions": [
#                         "Which parties or individuals are protected under the no-solicitation clause?",
#                         "What activities are restricted by the no-solicitation clause?",
#                         "How long does the no-solicitation restriction last?"
#                     ],
#                     "data_point_instructions": "Extract what categories of persons (e.g. employees, customers, suppliers) cannot be solicited and the activities that are restricted. Identify the duration of the clause and if the clause specifies any geographical limitation or other conditions."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "NoSolicitationAgent",
#                 "agent_instructions": "As the NoSolicitationAgent, your responsibility is to find and detail any no-solicitation clauses within the contract. Specifically, determine if such a clause exists. If so, identify who is protected by the clause (e.g. employees, clients) and the duration and scope of the restrictions, including any limitations or special conditions such as geography or time. Reference the relevant sections or clauses in the contract where this information is found."
#             }
#         },
#         {
#             "section_name": "Revenue and Profit Sharing",
#             "section_description": "Information regarding any clauses that detail revenue or profit sharing arrangements between the parties.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of Revenue/Profit Sharing Clause",
#                     "data_point_description": "Indicates whether the contract includes any revenue or profit sharing agreement between the parties.",
#                     "data_point_questions": [
#                         "Does the contract contain a clause specifying how revenues or profits will be shared between the parties?"
#                     ],
#                     "data_point_instructions": "Review the contract to determine if there is a revenue or profit sharing clause. If such a clause exists, document the presence and reference the contract sections that discuss how these earnings are to be shared."
#                 },
#                 {
#                     "data_point_name": "Revenue/Profit Sharing Terms",
#                     "data_point_description": "Details of the revenue or profit sharing arrangement including percentages, calculation methods, and distribution schedule.",
#                     "data_point_questions": [
#                         "What percentage of revenue or profit is allocated to each party?",
#                         "How is the revenue/profit calculated?",
#                         "What is the schedule for distributing shared revenues or profits?"
#                     ],
#                     "data_point_instructions": "Extract information on the distribution mechanism, such as how the share for each party is determined, the method for calculating the relevant revenue or profit, and the timing or schedule of payments. Note any special conditions that modify these terms, the relevant contract clauses, and any limitations on modifications."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "RevenueSharingAgent",
#                 "agent_instructions": "As the RevenueSharingAgent, your role is to locate and summarize any clauses in the contract that discuss revenue or profit sharing between the parties. You must determine whether the agreement provides for sharing revenue or profit, extract details on how shares are calculated, what percentages apply to each party, and the schedule or conditions for distributing shared earnings. If the contract references additional documents or schedules describing these terms, note those references. Provide precise references to relevant sections and summarize the terms clearly for easy reference."
#             }
#         },
#         {
#             "section_name": "Price Restrictions",
#             "section_description": "Information regarding any contract clauses imposing restrictions or setting specific conditions on pricing.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of Price Restriction Clause",
#                     "data_point_description": "Indicates whether the contract includes any clause that imposes restrictions on pricing, such as price floors or ceilings.",
#                     "data_point_questions": [
#                         "Does the contract contain any clause that restricts or sets conditions on the pricing of goods or services?"
#                     ],
#                     "data_point_instructions": "Review the contract to check if there's any mention of restricted pricing terms (like a fixed price, minimum price, maximum price, or conditions for adjusting prices). Document any such findings with references to the relevant contract sections."
#                 },
#                 {
#                     "data_point_name": "Price Restriction Terms",
#                     "data_point_description": "Details about any price restrictions, including the defined floors or ceilings, how pricing adjustments are calculated, and any conditions that trigger these terms.",
#                     "data_point_questions": [
#                         "What price restrictions are imposed by the contract?",
#                         "Are there conditions under which prices can be changed or adjusted?",
#                         "What method or formula is used to determine adjustments to the prices, if applicable?"
#                     ],
#                     "data_point_instructions": "Extract details on any price-related restrictions, listing any minimum or maximum pricing conditions, how adjustments or changes to prices are handled, and when they can be triggered. Note references to relevant contract sections and any formulas or external references used to determine pricing modifications."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "PriceRestrictionAgent",
#                 "agent_instructions": "As the PriceRestrictionAgent, you are to find and outline any clauses involving restrictions on product or service pricing outlined in the contract. Identify if such restrictions exist and then specify the terms and conditions, including any formula or schedule for adjustments. If no such restrictions are present, indicate that. Provide references to all relevant contract sections so the details are clearly verifiable."
#             }
#         },
#         {
#             "section_name": "Minimum Commitments",
#             "section_description": "Information regarding any clauses setting minimum purchase, sales, performance, or other commitments that one or both parties must meet.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of Minimum Commitment Clause",
#                     "data_point_description": "Indicates whether the contract includes any clause setting a minimum level of commitment for purchases, performance, or other obligations.",
#                     "data_point_questions": [
#                         "Does the contract require any party to commit to a minimum level of purchase, sales, or performance?"
#                     ],
#                     "data_point_instructions": "Check the contract for any clause that sets a baseline level of effort, purchase quantity, or performance metric that must be met. If such a clause exists, note the presence of this clause and reference the relevant contract section."
#                 },
#                 {
#                     "data_point_name": "Minimum Commitment Terms",
#                     "data_point_description": "Details regarding the specifics of any minimum commitments, including quantities, performance metrics, timeframes, and consequences of not meeting the commitments.",
#                     "data_point_questions": [
#                         "What specific minimum commitments are set by the contract?",
#                         "What are the timeframes associated with these commitments?",
#                         "What happens if the minimum commitments are not met? Are there penalties or remedies specified in the contract?"
#                     ],
#                     "data_point_instructions": "Extract the details outlining the nature of the commitments, including the required thresholds, relevant time periods, and any penalties or remedies for failing to meet these commitments. Reference the relevant contract sections where these terms are defined."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "MinimumCommitmentsAgent",
#                 "agent_instructions": "As the MinimumCommitmentsAgent, identify any contractual obligations requiring one or both parties to meet certain baseline commitments (like minimum sales or performance levels). Clearly outline the nature of these commitments, including the required thresholds, relevant time periods, and any consequences of failing to meet them. Provide references to the appropriate contract sections where these commitments are detailed."
#             }
#         },
#         {
#             "section_name": "Volume Restrictions",
#             "section_description": "Clauses addressing any restrictions on the quantity or volume of goods or services that can be purchased or sold under the contract.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of Volume Restriction Clause",
#                     "data_point_description": "Indicates whether the contract includes any clause that imposes volume restrictions on purchased or sold goods or services.",
#                     "data_point_questions": [
#                         "Does the contract contain any clause that specifies limits on the volume or quantity of goods or services that can be purchased or sold?"
#                     ],
#                     "data_point_instructions": "Search the contract for clauses specifying maximum or minimum volumes or quantities. If found, record their presence and reference the contract sections that indicate these volume restrictions."
#                 },
#                 {
#                     "data_point_name": "Volume Restriction Terms",
#                     "data_point_description": "Details on the volume restrictions specified in the contract, including exact quantities, conditions for these limits, and any repercussions for exceeding or not meeting these volumes.",
#                     "data_point_questions": [
#                         "What are the specific volume restrictions or limits?",
#                         "Under what conditions do these restrictions apply?",
#                         "Are there any penalties or remedies if these volume restrictions are not maintained?"
#                     ],
#                     "data_point_instructions": "Extract all terms related to volume restrictions including the quantities allowed, any conditions under which these restrictions apply, or exceptions when they do not. Note any contractual remedies or penalties for not adhering to these restrictions and reference the relevant sections in the contract."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "VolumeRestrictionsAgent",
#                 "agent_instructions": "As the VolumeRestrictionsAgent, find and detail any aVolume restrictions on the number of goods or services that can be purchased, sold, or supplied under the contract. Identify the exact limitations, conditions under which these restrictions apply, and what consequences exist for non-compliance. Provide references to relevant contract sections to support your findings."
#             }
#         },
#         {
#             "section_name": "Most Favored Nation Clause",
#             "section_description": "Details regarding any Most Favored Nation (MFN) clause which ensures a party receives terms as good as or better than those the other party gives to any other party.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of MFN Clause",
#                     "data_point_description": "Indicates whether the contract includes a Most Favored Nation clause, ensuring equal or better terms than those offered to others.",
#                     "data_point_questions": [
#                         "Does the contract contain a Most Favored Nation clause requiring a party to provide equal or better terms to the other party than those granted to any external party?"
#                     ],
#                     "data_point_instructions": "Check the contract for any clauses stating that a party must receive terms no worse than those offered to any other party. If found, note the presence and reference the relevant contract sections."
#                 },
#                 {
#                     "data_point_name": "MFN Clause Scope and Conditions",
#                     "data_point_description": "Details of the MFN clause, including what terms are protected, how compliance is monitored, and what adjustments or notifications are required if better terms are provided to others.",
#                     "data_point_questions": [
#                         "What are the specific terms or conditions covered by the MFN clause?",
#                         "How does the contract ensure compliance with the MFN clause?",
#                         "Are there any requirements for adjusting terms or notifying the relevant party if more favorable terms are offered to another party?"
#                     ],
#                     "data_point_instructions": "Extract information about the scope of the MFN clause. Include details about which elements (price, volume, or other conditions) are protected by the MFN status, how the party must demonstrate compliance or what procedures take place when new or more favorable terms are introduced. Provide references to relevant contract sections."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "MFNAgent",
#                 "agent_instructions": "As the MFNAgent, your responsibility is to identify whether the contract includes a Most Favored Nation clause. If it exists, summarize the scope of this clause, describing what contract terms are guaranteed to be as favorable as those offered to any other party and how compliance or enforcement is handled. Provide references to the relevant sections where these details are found."
#             }
#         },
#         {
#             "section_name": "Intellectual Property (IP) Ownership",
#             "section_description": "Information regarding ownership, assignment, or licensing of intellectual property created or used under the contract.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of IP Ownership Assignment Clause",
#                     "data_point_description": "Determines whether the contract includes an assignment of intellectual property rights to a party.",
#                     "data_point_questions": [
#                         "Does the contract include an assignment of intellectual property rights to any party?",
#                         "Which party retains ownership of any IP created under the contract?"
#                     ],
#                     "data_point_instructions": "Identify clauses accepting the ownership of IP resulting from the contract. Note which party is assigned the rights, whether IP is shared, and under what conditions. Provide references to the relevant sections of the contract."
#                 },
#                 {
#                     "data_point_name": "Licenses and Use of IP",
#                     "data_point_description": "Details of any licenses granted for the use of existing intellectual property and any restrictions on such use.",
#                     "data_point_questions": [
#                         "Does the contract grant licenses to use any existing IP?",
#                         "What are the terms and limitations of the license grants, if any?",
#                         "Are there any restrictions on how licensed IP can be used?"
#                     ],
#                     "data_point_instructions": "Extract information about any licenses provided under the contract. Specify which IP is licensed, the scope of the license (exclusive, non-exclusive), any usage restrictions, and any fees or royalties associated with the license. Provide references to the relevant sections."
#                 },
#                 {
#                     "data_point_name": "IP Protection and Enforcement",
#                     "data_point_description": "Indicates how the contract addresses the protection of IP rights and what actions can be taken to enforce these rights.",
#                     "data_point_questions": [
#                         "What measures are in place for the protection of IP rights?",
#                         "Are there provisions for enforcing IP rights, including infringement actions or indemnifications for IP breaches?",
#                         "How does the contract allocate responsibilities for defending against infringement claims?"
#                     ],
#                     "data_point_instructions": "Identify and document any clauses related to the protection of IP, how infringement claims should be handled, and who is responsible for enforcement or defense. Provide references to the relevant sections of the contract."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "IPAgent",
#                 "agent_instructions": "As the IPAgent, locate and extract all clauses related to intellectual property rights, ownership, and licensing. This includes identifying who retains ownership of IP created under the agreement, what licenses are granted, and any obligations the parties have regarding IP protection and enforcement. Summarize this information and reference the specific contract sections where these details can be found."
#             }
#         },
#         {
#             "section_name": "Liability and Indemnification",
#             "section_description": "Clauses outlining limitations of liability and indemnification obligations between the parties.",
#             "data_points": [
#                 {
#                     "data_point_name": "Limitation of Liability",
#                     "data_point_description": "Details if the contract includes limitations on liability and the extent of those limitations.",
#                     "data_point_questions": [
#                         "Does the contract limit the liability of any party?",
#                         "What is the scope of the limitation of liability clause?",
#                         "Which damages or losses are excluded or capped by this limitation?"
#                     ],
#                     "data_point_instructions": "Identify any clauses that limit the amount or types of damages recoverable by either party. Note the terms of these limitations, including whether certain types of damages (like incidental or consequential) are excluded. Provide references to relevant sections."
#                 },
#                 {
#                     "data_point_name": "Cap on Liability",
#                     "data_point_description": "Information on any financial cap on the amount that can be recovered in damages.",
#                     "data_point_questions": [
#                         "Is there a specific numeric limit or formula for calculating the maximum liability under the contract?",
#                         "Which types of claims or damages does the cap on liability apply to?"
#                     ],
#                     "data_point_instructions": "If the contract sets a financial limit on recoverable damages, specify the limit and how it applies to different types of claims. Provide references to relevant contract sections and note any exceptions or special conditions."
#                 },
#                 {
#                     "data_point_name": "Uncapped Liability",
#                     "data_point_description": "Whether liabilities for certain breaches or claims are uncapped and not limited by the contract.",
#                     "data_point_questions": [
#                         "Are there any liabilities that are explicitly stated as uncapped or unlimited under the contract?",
#                         "For which types of breaches or claims does uncapped liability apply?"
#                     ],
#                     "data_point_instructions": "Identify any instances where the contract states that certain liabilities are not subject to the general limitations or caps on liability, such as for willful misconduct or IP infringement claims. Provide references to relevant sections."
#                 },
#                 {
#                     "data_point_name": "Indemnification Obligations",
#                     "data_point_description": "Details of any indemnification responsibilities one party has towards another party in this contract.",
#                     "data_point_questions": [
#                         "Does the contract include indemnification clauses requiring one party to cover certain losses or damages of the other party?",
#                         "What events or types of claims trigger indemnification obligations?",
#                         "What are the scope and limitations of the indemnification?"
#                     ],
#                     "data_point_instructions": "Extract clauses that require a party to compensate the other for certain losses or damages incurred. Note what triggers these obligations, the scope of coverage, limitations or exceptions, and references to the relevant sections of the contract."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "LiabilityAgent",
#                 "agent_instructions": "As the LiabilityAgent, analyze the contract for any provisions regarding liability limitations, whether general or specific to certain types of claims, and indemnification obligations. Carefully document the specifics, including any caps on liability, instances of uncapped liability, and the details of indemnification obligations. Provide references to the relevant contract sections for easy verification of these details."
#             }
#         },
#         {
#             "section_name": "Liquidated Damages",
#             "section_description": "Information about any clauses specifying predetermined damages that must be paid if the contract is breached.",
#             "data_points": [
#                 {
#                     "data_point_name": "Existence of Liquidated Damages Clause",
#                     "data_point_description": "Indicates whether the contract includes a clause that provides for liquidated damages in the event of a breach.",
#                     "data_point_questions": [
#                         "Does the contract specify any predetermined amount of damages (liquidated damages) to be paid by a breaching party?"
#                     ],
#                     "data_point_instructions": "Search for any clause that sets a specific amount or formula for damages in case of a breach. Document the existence of such a clause and reference the relevant contract section."
#                 },
#                 {
#                     "data_point_name": "Liquidated Damages Terms",
#                     "data_point_description": "Details about the predetermined damages, including how the amount is calculated and under what circumstances these damages apply.",
#                     "data_point_questions": [
#                         "How are the liquidated damages calculated? Is there a fixed amount or formula?",
#                         "Under what conditions or types of breaches do liquidated damages apply?",
#                         "Are there any limitations or caps on these liquidated damages?"
#                     ],
#                     "data_point_instructions": "If the contract includes a liquidated damages clause, extract the specific amount or calculation method, note the conditions under which liquidated damages become payable, and identify any limitations. Provide references to relevant sections."
#                 }
#             ],
#             "section_agent": {
#                 "agent_name": "LiquidatedDamagesAgent",
#                 "agent_instructions": "As the LiquidatedDamagesAgent, identify any clauses in the contract that specify predetermined damages that a party must pay in the event of a breach. Summarize these clauses, including how the damage amounts are calculated, what triggers them, and any exceptions or conditions. Provide references to the specific sections of the contract with these details."
#             }
#         }
#     ]
# }

# %%
o1_planner.save_plan(o1_output_file_path)

# %% [markdown]
# ## Executor Agent

# %%
from src.agents.plan_executor import PlanExecutor
plan_path = '/Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/gpt-4o/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.json'
contract_path = '/Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt'

# %%
gpt_executor = PlanExecutor(
    plan_path = plan_path,
    contract_path = contract_path,
    model = 'gpt-4o-mini',
    temp = 0.7,
    debug = True
)
# Out:
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/gpt-4o/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt

# %%
gpt_executor.execute_plan()
# Out:
# Processing section: Parties Involved
#
# Agent: PartiesAgent
#
# System Prompt:
# You are PartiesAgent. Your role is to extract information for the section 'Parties Involved' of the contract.
#
#             As the PartiesAgent, your responsibility is to extract information about the parties involved in the contract. Focus on identifying the names and contact details of both the Licensor and the Licensee. Ensure accuracy in documenting this information as it is critical for understanding the roles and responsibilities within the contract.
#
#             # Section Description
#
#             Details about the parties involved in the contract, including their roles and contact information.
#
#             # Data Points to Extract
#
#                 ## Data Point Name: Licensor
#                 - Description: The entity granting the license for the software, along with its contact details.
#                 - Questions: Who is the Licensor in this agreement?, What are the contact details of the Licensor?
#                 - Instructions: Identify the entity designated as the Licensor and note their name and contact information as stated in the contract.
#
#                 ## Data Point Name: Licensee
#                 - Description: The entity receiving the license for the software, along with its contact details.
#                 - Questions: Who is the Licensee in this agreement?, What are the contact details of the Licensee?
#                 - Instructions: Identify the entity designated as the Licensee and note their name and contact information as stated in the contract.
#
#
#             # Instructions:
#
#             - Carefully read the contract provided in the user prompt.
#             - Sequentially process each data point listed above.
#             - For each data point, provide the following information:
#             - **data_point_name**: Copy verbatim from the data point name provided.
#             - **data_point_description**: Copy verbatim from the data point description provided.
#             - **data_point_questions**: Copy verbatim from the data point questions provided.
#             - **data_point_overview**: Summarize all the information collected for the data point.
#             - **data_point_answers**: Answer each of the data point questions in separate paragraphs.
#             - **data_point_verbatim**: Provide the exact text from the contract that was used to collect the data point.
#
#             - Provide the extracted data points in the following JSON format:
#
#             {
#                 "data_points": [
#                     {
#                         "data_point_name": "...",
#                         "data_point_description": "...",
#                         "data_point_questions": ["...", "..."],
#                         "data_point_overview": "...",
#                         "data_point_answers": "...",
#                         "data_point_verbatim": "..."
#                     }
#                     // Include additional data points as needed
#                 ]
#             }
#
#             # Output Format
#             ```json
#                             {
#                 "$defs": {
#                     "DataPoint": {
#                     "properties": {
#                         "data_point_name": {
#                         "description": "The name of the data point for which the agent collected the information. Should be copied verbatim from the data point name in the plan.",
#                         "title": "Data Point Name",
#                         "type": "string"
#                         },
#                         "data_point_description": {
#                         "description": "A description of what is contained in the data point. Should be copied verbatim from the data point description in the plan.",
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# data_points=[DataPoint(data_point_name='Licensor', data_point_description='The entity granting the license for the software, along with its contact details.', data_point_questions=['Who is the Licensor in this agreement?', 'What are the contact details of the Licensor?'], data_point_overview='The Licensor in this agreement is D2 Technologies, Inc., a California corporation.', data_point_answers='The Licensor in this agreement is D2 Technologies, Inc.\n\nThe contact details of the Licensor are: 104 West Anapamu Street, Santa Barbara, CA 93101.', data_point_verbatim='by and between D2 Technologies, Inc., a California corporation with offices at 104 West Anapamu Street, Santa Barbara, CA 93101'), DataPoint(data_point_name='Licensee', data_point_description='The entity receiving the license for the software, along with its contact details.', data_point_questions=['Who is the Licensee in this agreement?', 'What are the contact details of the Licensee?'], data_point_overview='The Licensee in this agreement is Summa Four Inc., a Delaware corporation.', data_point_answers='The Licensee in this agreement is Summa Four Inc.\n\nThe contact details of the Licensee are: 25 Sundial Avenue, Manchester, New Hampshire 03103-7251.', data_point_verbatim='and Summa Four Inc., a Delaware corporation with offices at 25 Sundial Avenue, Manchester, New Hampshire 03103-7251')]
# Processing section: License Terms
#
# Agent: LicenseTermsAgent
#
# System Prompt:
# You are LicenseTermsAgent. Your role is to extract information for the section 'License Terms' of the contract.
#
#             Your role as the LicenseTermsAgent is to collect all relevant information about the licensing terms specified in the contract. Focus on the scope, duration, and any associated fees. Pay attention to any restrictions on usage and ensure that all financial obligations are clearly documented.
#
#             # Section Description
#
#             Details about the licensing terms, including scope, duration, and any restrictions or fees associated with the license.
#
#             # Data Points to Extract
#
#                 ## Data Point Name: License Scope
#                 - Description: The scope of the license granted, including any restrictions on usage.
#                 - Questions: What is the scope of the license granted to the Licensee?, Are there any restrictions on how the Licensed Technology can be used?
#                 - Instructions: Identify the sections that outline what the Licensee is permitted to do with the Licensed Technology, including any restrictions on its use.
#
#                 ## Data Point Name: License Duration
#                 - Description: The duration for which the license is valid.
#                 - Questions: Is the license granted to the Licensee perpetual or fixed-term?, If fixed-term, what is the duration of the license?
#                 - Instructions: Determine whether the license is perpetual or has a fixed duration and note any relevant time frames mentioned in the contract.
#
#                 ## Data Point Name: License Fees
#                 - Description: Fees associated with the license, including development and runtime license fees.
#                 - Questions: What are the development license fees specified in the contract?, What are the runtime license fees and how are they calculated?
#                 - Instructions: Extract information regarding any fees the Licensee must pay, including development and runtime fees, and describe how these fees are structured and calculated.
#
#
#             # Instructions:
#
#             - Carefully read the contract provided in the user prompt.
#             - Sequentially process each data point listed above.
#             - For each data point, provide the following information:
#             - **data_point_name**: Copy verbatim from the data point name provided.
#             - **data_point_description**: Copy verbatim from the data point description provided.
#             - **data_point_questions**: Copy verbatim from the data point questions provided.
#             - **data_point_overview**: Summarize all the information collected for the data point.
#             - **data_point_answers**: Answer each of the data point questions in separate paragraphs.
#             - **data_point_verbatim**: Provide the exact text from the contract that was used to collect the data point.
#
#             - Provide the extracted data points in the following JSON format:
#
#             {
#                 "data_points": [
#                     {
#                         "data_point_name": "...",
#                         "data_point_description": "...",
#                         "data_point_questions": ["...", "..."],
#                         "data_point_overview": "...",
#                         "data_point_answers": "...",
#                         "data_point_verbatim": "..."
#                     }
#                     // Include additional data points as needed
#                 ]
#             }
#
#             # Output Format
#             ```json
#                             {
#                 "$defs": {
#                     "DataPoint": {
#                     "properties": {
#                         "data_point_name": {
#                         "description": "The name of the data point for which the agent collected the information. Should be copied verbatim from the data point name in the plan.",
#                         "title": "Data Point Name",
#                         "type": "string"
#                         },
#                         "data_point_description": {
#                         "description": "A description of what is contained in the data point. Should be copied verbatim from the data point description in the plan.",
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# data_points=[DataPoint(data_point_name='License Scope', data_point_description='The scope of the license granted, including any restrictions on usage.', data_point_questions=['What is the scope of the license granted to the Licensee?', 'Are there any restrictions on how the Licensed Technology can be used?'], data_point_overview='The license granted to LICENSEE is perpetual, non-exclusive, and worldwide, allowing the use of Licensed Technology solely as part of the Licensee Product. LICENSEE may modify, create derivative works, reproduce, develop, and distribute the Licensed Technology, with some restrictions on the use of the Licensed Source Code.', data_point_answers='The license granted to LICENSEE is a perpetual, non-exclusive, worldwide license to use the Licensed Technology in Object Code format only as part of the Licensee Product. LICENSEE is permitted to modify, create derivative works of, reproduce, and distribute the Licensed Technology.\n\nThere are restrictions on the usage of the Licensed Technology, specifically that the Licensed Source Code can only be used for maintenance functions, and LICENSEE must ensure that all distributed Licensed Technology is subjected to appropriate end-user agreements to protect intellectual property rights.', data_point_verbatim='2.2 License to LICENSEE. (i) Subject to the terms and conditions of this Agreement, D2 hereby grants LICENSEE a perpetual non-exclusive, worldwide license, to use Licensed Technology in Object Code format only as an incorporated part of the Licensee Product. For this purpose, LICENSEE may also modify, create derivative works of and reproduce and have reproduced the Licensed Technology, and to develop, use, market and distribute (directly or through third parties) Licensed Technology, or modifications or derivative works of the Licensed Technology created by or for LICENSEE.'), DataPoint(data_point_name='License Duration', data_point_description='The duration for which the license is valid.', data_point_questions=['Is the license granted to the Licensee perpetual or fixed-term?', 'If fixed-term, what is the duration of the license?'], data_point_overview='The license granted to LICENSEE is perpetual, meaning it does not have a predetermined end date and will continue as long as the agreement is in effect.', data_point_answers='The license granted to LICENSEE is perpetual, meaning it does not expire and remains in effect indefinitely unless terminated in accordance with the provisions of the agreement.', data_point_verbatim='2.2 License to LICENSEE. (i) Subject to the terms and conditions of this Agreement, D2 hereby grants LICENSEE a perpetual non-exclusive, worldwide license...'), DataPoint(data_point_name='License Fees', data_point_description='Fees associated with the license, including development and runtime license fees.', data_point_questions=['What are the development license fees specified in the contract?', 'What are the runtime license fees and how are they calculated?'], data_point_overview="The contract specifies development license fees that are to be paid in two installments, as well as runtime license fees calculated based on the number of ports provided by the Licensee's product. The maintenance fee is also specified.", data_point_answers='The development license fees are specified in PO #104962, with 50% already paid and the remaining 50% due upon delivery and acceptance of the Licensed Technology.\n\nThe runtime license fees are calculated based on the number of service ports the SRM provides, with a formula given in the agreement: Fee_per_SRM = Fee_per_Port * DSPs_per_SRM * Average_Ports_per_DSP. The runtime license fees have a cap and may be subject to credits based on the total amount paid over a specified period.', data_point_verbatim='DEVELOPMENT LICENSE FEES: LICENSED TECHNOLOGY FOR THE BASIC SERVICES SPECIFIED IN EXHIBIT A\n\nDevelopment license fees are specified in PO #104962.\n\nRUNTIME LICENSE FEES: LICENSED TECHNOLOGY FOR BASIC ...
# Processing section: Intellectual Property Rights
#
# Agent: IPAgent
#
# System Prompt:
# You are IPAgent. Your role is to extract information for the section 'Intellectual Property Rights' of the contract.
#
#             As the IPAgent, your task is to identify and document all clauses related to intellectual property rights. Focus on ownership, any rights granted to the Licensee for modifications, and protections implemented to safeguard these rights. Make sure to capture all confidentiality obligations.
#
#             # Section Description
#
#             Clauses related to the ownership and assignment of intellectual property rights in the contract.
#
#             # Data Points to Extract
#
#                 ## Data Point Name: IP Ownership
#                 - Description: Details on who retains ownership of the intellectual property after the licensing agreement.
#                 - Questions: Who retains ownership of the Licensed Technology under the contract?, Does the Licensee have any rights to modify or create derivative works from the Licensed Technology?
#                 - Instructions: Identify who holds the IP rights according to the contract and any rights the Licensee has to modify the technology.
#
#                 ## Data Point Name: IP Protection Measures
#                 - Description: Measures in place to protect the intellectual property rights of the Licensor.
#                 - Questions: What measures are in place to protect the Licensor's IP?, Are there any confidentiality obligations related to the IP?
#                 - Instructions: Extract clauses that outline protections for the Licensor’s IP, including confidentiality obligations.
#
#
#             # Instructions:
#
#             - Carefully read the contract provided in the user prompt.
#             - Sequentially process each data point listed above.
#             - For each data point, provide the following information:
#             - **data_point_name**: Copy verbatim from the data point name provided.
#             - **data_point_description**: Copy verbatim from the data point description provided.
#             - **data_point_questions**: Copy verbatim from the data point questions provided.
#             - **data_point_overview**: Summarize all the information collected for the data point.
#             - **data_point_answers**: Answer each of the data point questions in separate paragraphs.
#             - **data_point_verbatim**: Provide the exact text from the contract that was used to collect the data point.
#
#             - Provide the extracted data points in the following JSON format:
#
#             {
#                 "data_points": [
#                     {
#                         "data_point_name": "...",
#                         "data_point_description": "...",
#                         "data_point_questions": ["...", "..."],
#                         "data_point_overview": "...",
#                         "data_point_answers": "...",
#                         "data_point_verbatim": "..."
#                     }
#                     // Include additional data points as needed
#                 ]
#             }
#
#             # Output Format
#             ```json
#                             {
#                 "$defs": {
#                     "DataPoint": {
#                     "properties": {
#                         "data_point_name": {
#                         "description": "The name of the data point for which the agent collected the information. Should be copied verbatim from the data point name in the plan.",
#                         "title": "Data Point Name",
#                         "type": "string"
#                         },
#                         "data_point_description": {
#                         "description": "A description of what is contained in the data point. Should be copied verbatim from the data point description in the plan.",
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# data_points=[DataPoint(data_point_name='IP Ownership', data_point_description='Details on who retains ownership of the intellectual property after the licensing agreement.', data_point_questions=['Who retains ownership of the Licensed Technology under the contract?', 'Does the Licensee have any rights to modify or create derivative works from the Licensed Technology?'], data_point_overview="D2 Technologies retains ownership of the Licensed Technology, while the Licensee retains ownership rights in modifications to the Licensed Source Code made by them, subject to D2's ownership rights in the underlying Licensed Technology.", data_point_answers='D2 Technologies, Inc. retains all right, title, and interest in and to the Licensed Technology as specified in Article 2.1 of the Agreement. However, the Licensee retains ownership rights in modifications made to the Licensed Source Code under the license granted in Article 2.2.\n\nYes, the Licensee has the rights to modify the Licensed Technology and create derivative works as per Article 2.2 (i).', data_point_verbatim='2.1 Ownership. Subject to the rights granted to LICENSEE in this Agreement, D2 owns all right, title and interest in and to the Licensed Technology. Notwithstanding the foregoing, LICENSEE shall retain all right, title and interest in and to modifications to the Licensed Source Code made by LICENSEE pursuant to the license in Article 2.2 below.'), DataPoint(data_point_name='IP Protection Measures', data_point_description='Measures in place to protect the intellectual property rights of the Licensor.', data_point_questions=["What measures are in place to protect the Licensor's IP?", 'Are there any confidentiality obligations related to the IP?'], data_point_overview="The Agreement implements various measures to protect the Licensor's intellectual property, including confidentiality obligations regarding the Licensed Source Code and the Licensed Technology. Additionally, the Licensee must ensure that all employees and contractors sign agreements that protect the confidentiality of the Licensed Source Code.", data_point_answers="To protect the Licensor's IP, the Licensee is required to use the Licensed Source Code only as expressly licensed and not to disclose it to third parties except as provided in the Agreement. The Licensee must also implement strict control over access to the Licensed Source Code and inform employees about its confidential nature.\n\nYes, there are confidentiality obligations related to the IP. The Licensee must treat the Licensed Source Code as confidential, restrict access to it, and notify the Licensor of any breaches of security regarding the Licensed Source Code.", data_point_verbatim="7.4 (A) General. LICENSEE acknowledges and agrees that the Licensed Source Code constitutes the confidential and proprietary trade secrets of D2, and that LICENSEE's protection thereof is essential to this Agreement and a condition of LICENSEE's use and possession of the Licensed Source Code. LICENSEE shall retain in strict confidence any and all elements of the Licensed Source Code and use the Licensed Source Code only as expressly licensed herein.")]
# Processing section: Maintenance and Support
#
# Agent: SupportAgent
#
# System Prompt:
# You are SupportAgent. Your role is to extract information for the section 'Maintenance and Support' of the contract.
#
#             Your role as the SupportAgent is to gather all information related to maintenance and support obligations as specified in the contract. Focus on the types of services provided, any associated fees, and specific contact details for support. Ensure clarity in understanding the provider’s obligations and any conditions affecting fees.
#
#             # Section Description
#
#             Maintenance and support obligations and related fees as outlined in the contract.
#
#             # Data Points to Extract
#
#                 ## Data Point Name: Maintenance Obligations
#                 - Description: Details on the maintenance services the Licensor is obligated to provide.
#                 - Questions: What maintenance services is the Licensor required to provide?, Is there a minimum period for which maintenance is guaranteed?
#                 - Instructions: Identify the sections detailing the maintenance services, including any minimum periods specified.
#
#                 ## Data Point Name: Support Services
#                 - Description: Details on support services provided by the Licensor.
#                 - Questions: What support services are included in the contract?, Are there any specific contact persons for support?
#                 - Instructions: Extract information about the support services and any designated contact persons for support.
#
#                 ## Data Point Name: Maintenance and Support Fees
#                 - Description: Fees associated with maintenance and support services.
#                 - Questions: What are the fees for maintenance and support services post-warranty period?, Are there conditions under which these fees may be waived or reduced?
#                 - Instructions: Identify and document the fees for maintenance and support services, including any conditions for waivers or reductions.
#
#
#             # Instructions:
#
#             - Carefully read the contract provided in the user prompt.
#             - Sequentially process each data point listed above.
#             - For each data point, provide the following information:
#             - **data_point_name**: Copy verbatim from the data point name provided.
#             - **data_point_description**: Copy verbatim from the data point description provided.
#             - **data_point_questions**: Copy verbatim from the data point questions provided.
#             - **data_point_overview**: Summarize all the information collected for the data point.
#             - **data_point_answers**: Answer each of the data point questions in separate paragraphs.
#             - **data_point_verbatim**: Provide the exact text from the contract that was used to collect the data point.
#
#             - Provide the extracted data points in the following JSON format:
#
#             {
#                 "data_points": [
#                     {
#                         "data_point_name": "...",
#                         "data_point_description": "...",
#                         "data_point_questions": ["...", "..."],
#                         "data_point_overview": "...",
#                         "data_point_answers": "...",
#                         "data_point_verbatim": "..."
#                     }
#                     // Include additional data points as needed
#                 ]
#             }
#
#             # Output Format
#             ```json
#                             {
#                 "$defs": {
#                     "DataPoint": {
#                     "properties": {
#                         "data_point_name": {
#                         "description": "The name of the data point for which the agent collected the information. Should be copied verbatim from the data point name in the plan.",
#                         "title": "Data Point Name",
#                         "type": "string"
#                         },
#                         "data_point_description": {
#                         "description": "A description of what is contained in the data point. Should be copied verbatim from the data point description in the plan.",
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# data_points=[DataPoint(data_point_name='Maintenance Obligations', data_point_description='Details on the maintenance services the Licensor is obligated to provide.', data_point_questions=['What maintenance services is the Licensor required to provide?', 'Is there a minimum period for which maintenance is guaranteed?'], data_point_overview='D2 is obligated to provide maintenance and support services which include updates and error corrections for the Licensed Technology. These services are to be provided for a minimum of five years after acceptance of the Licensed Technology, with specific obligations to correct defects based on their priority.', data_point_answers='The Licensor, D2, is required to provide maintenance services including updates and maintenance of the Licensed Technology. D2 must release at least one Update or New Version each year and provide one copy of any Updates or New Versions to LICENSEE as soon as they become available.\n\nThe minimum period for which maintenance is guaranteed is five years after acceptance of the Licensed Technology, ensuring that D2 provides maintenance and support for this duration.', data_point_verbatim='6.1 Maintenance and Support Obligation, Fees. On the date of expiry of the Warranty period defined in Article 8.3, and on any anniversary of the expiry date, LICENSEE may in its sole discretion pay D2 a "Maintenance and Support Fee" according to Exhibit C. In return for payment of such fee, D2 shall provide LICENSEE with the maintenance and support set forth in this Article 6 for a period of twelve months (the "Contract Year"). In any event, D2 shall provide support and maintenance services to Licensee during the Warranty period in breadth and scope which is no less than the support and maintenance services described in this Article. D2 shall make available to LICENSEE the maintenance and support services according to the terms of this Article 6 for a minimum of five years after Acceptance of Licensed Technology.'), DataPoint(data_point_name='Support Services', data_point_description='Details on support services provided by the Licensor.', data_point_questions=['What support services are included in the contract?', 'Are there any specific contact persons for support?'], data_point_overview='D2 is committed to providing a range of support services throughout the warranty period and for subsequent years if support is purchased. These services include assistance with programming errors, installation inquiries, and problem resolution. D2 will assign a qualified technical staff member as the Technical Contact for support coordination.', data_point_answers='The support services included in the contract consist of assistance in determining if problems are caused by programming errors in the Licensed Technology, answering installation questions, and helping in resolving issues arising from the normal use of the Licensed Technology.\n\nD2 shall appoint a qualified technical staff member as the "Technical Contact" available during D2\'s normal business hours. If the Technical Contact is unavailable, a backup Technical Contact will be assigned temporarily.', data_point_verbatim='6.4 Support. D2 will provide the following support to LICENSEE throughout the Warranty period and for those subsequent years for which support has been purchased by Licensee: (i) D2 will assist LICENSEE in determining if problems encountered by LICENSEE are caused by programming errors in the Licensed Technology. (ii) D2 will answer questions concerning the installation of Licensed Technology. (iii) D2 will assist LICENSEE in resolving LICENSEE\'s problems, if any, arising from the normal usage of the Licensed Technology. (iv) D2 shall appoint a qualified technical staff as the "Technical Contact" to co-ordinate all support and maintenance services. The "Technical Contact" shall be available to LICENSEE during D2\'s normal business hours; in the event that appointed "Technical Contact" is not available, a back-up "Techn ...
# Processing section: Liability and Indemnification
#
# Agent: LiabilityAgent
#
# System Prompt:
# You are LiabilityAgent. Your role is to extract information for the section 'Liability and Indemnification' of the contract.
#
#             As the LiabilityAgent, your task is to thoroughly analyze the contract for any provisions related to liability limitations and indemnification. Document the specifics, including any caps on liability and circumstances under which indemnification is required. Be meticulous in noting any exceptions or special conditions.
#
#             # Section Description
#
#             Clauses related to the limitation of liability and indemnification obligations in the contract.
#
#             # Data Points to Extract
#
#                 ## Data Point Name: Limitation of Liability
#                 - Description: Details on any limitations of liability for either party under the contract.
#                 - Questions: Are there any limitations on liability for either party?, What is the maximum liability cap, if any, specified in the contract?
#                 - Instructions: Identify clauses that limit the liability of either party and specify any caps on liability mentioned.
#
#                 ## Data Point Name: Indemnification Obligations
#                 - Description: Details of indemnification obligations one party has towards the other.
#                 - Questions: What indemnification obligations are specified in the contract?, Under what circumstances can indemnification be claimed?
#                 - Instructions: Extract information about indemnification responsibilities, including conditions under which indemnification can be claimed.
#
#
#             # Instructions:
#
#             - Carefully read the contract provided in the user prompt.
#             - Sequentially process each data point listed above.
#             - For each data point, provide the following information:
#             - **data_point_name**: Copy verbatim from the data point name provided.
#             - **data_point_description**: Copy verbatim from the data point description provided.
#             - **data_point_questions**: Copy verbatim from the data point questions provided.
#             - **data_point_overview**: Summarize all the information collected for the data point.
#             - **data_point_answers**: Answer each of the data point questions in separate paragraphs.
#             - **data_point_verbatim**: Provide the exact text from the contract that was used to collect the data point.
#
#             - Provide the extracted data points in the following JSON format:
#
#             {
#                 "data_points": [
#                     {
#                         "data_point_name": "...",
#                         "data_point_description": "...",
#                         "data_point_questions": ["...", "..."],
#                         "data_point_overview": "...",
#                         "data_point_answers": "...",
#                         "data_point_verbatim": "..."
#                     }
#                     // Include additional data points as needed
#                 ]
#             }
#
#             # Output Format
#             ```json
#                             {
#                 "$defs": {
#                     "DataPoint": {
#                     "properties": {
#                         "data_point_name": {
#                         "description": "The name of the data point for which the agent collected the information. Should be copied verbatim from the data point name in the plan.",
#                         "title": "Data Point Name",
#                         "type": "string"
#                         },
#                         "data_point_description": {
#                         "description": "A description of what is contained in the data point. Should be copied verbatim from the data point description in the plan.",
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# ...
#      'data_point_verbatim': '6.4 Support. D2 will provide the following support to LICENSEE throughout the Warranty period and for those subsequent years for which support has been purchased by Licensee: (i) D2 will assist LICENSEE in determining if problems encountered by LICENSEE are caused by programming errors in the Licensed Technology. (ii) D2 will answer questions concerning the installation of Licensed Technology. (iii) D2 will assist LICENSEE in resolving LICENSEE\'s problems, if any, arising from the normal usage of the Licensed Technology. (iv) D2 shall appoint a qualified technical staff as the "Technical Contact" to co-ordinate all support and maintenance services. The "Technical Contact" shall be available to LICENSEE during D2\'s normal business hours; in the event that appointed "Technical Contact" is not available, a back-up "Technical Contact" shall be temporarily assigned and LICENSEE shall be notified.'},
#     {'data_point_name': 'Maintenance and Support Fees',
#      'data_point_description': 'Fees associated with maintenance and support services.',
#      'data_point_questions': ['What are the fees for maintenance and support services post-warranty period?',
#       'Are there conditions under which these fees may be waived or reduced?'],
#      'data_point_overview': 'The maintenance and support fee is set at $20,000 per year following the warranty period. There are provisions for fee waivers or reductions if certain conditions regarding runtime license fees are met.',
#      'data_point_answers': 'The fees for maintenance and support services after the warranty period are $20,000 per year, starting after the warranty period expires and renewable at the end of each Contract Year.\n\nThere are conditions under which these fees may be waived or reduced. If LICENSEE completes payments of $100,000 in Runtime License Fees during the four consecutive calendar quarters following the start of a Contract Year, D2 will apply a credit equal to 100% of the Maintenance Fee against the Runtime License Fees of that Contract Year. Additionally, if the Buy Out option is exercised, there will be no Maintenance Fee for the first three years after the warranty period.',
#      'data_point_verbatim': '6.1 Maintenance and Support Obligation, Fees. ... The Maintenance Fee after the expiry of the Warranty period shall be $20,000 per year, starting from the date after the Warranty period (Contract Year), renewable at the end of each Contract Year. In the event that during the four consecutive calendar quarters which begin immediately after the start of a Contract Year, LICENSEE completes payments to D2 of one hundred thousand dollars in Runtime License Fees under this Agreement, D2 will apply a credit equaling to 100% of the Maintenance Fee against the Runtime License Fees of that Contract Year. In the event that LICENSEE exercises the Buy Out option for Runtime License Fees, there shall be no Maintenance Fee for the first three years after the expiry of the Warranty period.'}]},
#   {'section_name': 'Liability and Indemnification',
#    'section_description': 'Clauses related to the limitation of liability and indemnification obligations in the contract.',
#    'data_points': [{'data_point_name': 'Limitation of Liability',
#      'data_point_description': 'Details on any limitations of liability for either party under the contract.',
#      'data_point_questions': ['Are there any limitations on liability for either party?',
#       'What is the maximum liability cap, if any, specified in the contract?'],
#      'data_point_overview': "The contract establishes certain limitations on liability for both parties. Specifically, it prohibits claims for lost profits or any consequential, special, incidental, or indirect damages. Additionally, D2's liability is capped at the total amount paid or owed by LICENSEE under the Agreement.",
#      'data_point_answers': "Yes, there are limitations on liability for both parties as specified in the contract. These limitations include the exclusion of liability for lost profits and indirect damages.\n\nThe maximum liability cap specified in the contract states that D2's liability shall not exceed the total amount paid or owed by LICENSEE to D2 under this Agreement.",
#      'data_point_verbatim': "IN NO EVENT SHALL EITHER PARTY BE LIABLE TO THE OTHER PARTY FOR LOST PROFITS OR ANY CONSEQUENTIAL, SPECIAL, INCIDENTAL, OR INDIRECT DAMAGES OR SUCH OTHER PARTY, HOWEVER CAUSED AND ON ANY THEORY OF LIABILITY, ARISING OUT OF THIS AGREEMENT. THESE LIMITATIONS SHALL APPLY NOTWITHSTANDING ANY FAILURE OF ESSENTIAL PURPOSE OF ANY LIMITED REMEDY. IN NO EVENT SHALL D2'S LIABILITY HEREUNDER EXCEED THE TOTAL AMOUNT PAID OR OWED BY LICENSEE TO D2 UNDER THIS AGREEMENT."},
#     {'data_point_name': 'Indemnification Obligations',
#      'data_point_description': 'Details of indemnification obligations one party has towards the other.',
#      'data_point_questions': ['What indemnification obligations are specified in the contract?',
#       'Under what circumstances can indemnification be claimed?'],
#      'data_point_overview': "The contract outlines D2's indemnification obligations towards LICENSEE. D2 is required to indemnify and hold LICENSEE harmless against costs, losses, or liabilities arising from breaches of D2's warranties or third-party claims of infringement related to the Licensed Technology.",
#      'data_point_answers': "D2 is obligated to indemnify LICENSEE against any costs, losses, liabilities, or expenses arising from breaches of D2's warranties or from third-party claims alleging that the Licensed Technology infringes on intellectual property rights.\n\nIndemnification can be claimed under circumstances where LICENSEE notifies D2 promptly about such claims and gives D2 sole control over the defense or settlement of these claims. However, indemnification will not apply if the claims arise from LICENSEE's unauthorized modifications of the Licensed Technology.",
#      'data_point_verbatim': "D2 agrees to indemnify and hold LICENSEE harmless against any cost, loss, liability, or expense (including attorney's fees) arising out of any breach of D2's warranties hereunder, or out of third party claims against LICENSEE alleging that the Licensed Technology, or LICENSEE's use or distribution of the Licensed Technology as set forth in this Agreement, infringes any third party's patent, trade secret, copyright of other intellectual property right in any country, provided that LICENSEE shall (i) notify D2 promptly in writing of such claims, and (ii) give D2 sole control of the defense or settlement of such claims."}]},
#   {'section_name': 'Termination Conditions',
#    'section_description': 'Conditions under which the contract can be terminated by either party, including any post-termination obligations.',
#    'data_points': [{'data_point_name': 'Termination Rights',
#      'data_point_description': 'The rights of each party to terminate the contract and under what circumstances.',
#      'data_point_questions': ['Under what conditions can the contract be terminated by either party?',
#       'Is there a required notice period prior to termination?'],
#      'data_point_overview': 'The contract can be terminated by either party under specific conditions including convenience and default. The notice period required for termination by the LICENSEE is ninety (90) days, while for termination due to default, a thirty (30) day correction period is provided after written notice.',
#      'data_point_answers': 'The contract can be terminated by either party for convenience with a ninety (90) days written notice. Additionally, if either party defaults on their material obligations and does not rectify the default within thirty (30) days following written notice, the non-defaulting party may terminate the agreement by providing written notice of termination to the defaulting party.\n\nThe required notice period prior to termination is ninety (90) days for convenience. In the case of default, a written notice must be given, followed by a thirty (30) day period for correction.',
#      'data_point_verbatim': '9.1 Term. This Agreement shall become effective on the Effective Date and shall continue in effect until terminated in accordance with the provisions of this Article 9.\n\n9.2 For Convenience. LICENSEE may terminate this Agreement upon ninety (90) days written notice.\n\n9.3 Default. If either party defaults in the performance of any of its material obligations hereunder and if such default is not corrected within thirty (30) days after written notice thereof by the other party, then the nondefaulting party, at its option, may, in addition to any other remedies it may have, terminate this Agreement by giving written notice of termination to the defaulting party.'},
#     {'data_point_name': 'Post-Termination Obligations',
#      'data_point_description': 'Obligations that survive the termination of the contract.',
#      'data_point_questions': ['What obligations continue after termination?',
#       'Are there any ongoing confidentiality or non-compete obligations?'],
#      'data_point_overview': 'Several obligations survive the termination of the contract, specifically those related to confidentiality and certain provisions outlined in various articles. The confidentiality obligations, particularly those relating to the Licensed Source Code, will persist for five (5) years after disclosure.',
#      'data_point_answers': 'After termination, obligations that continue include those specified in Articles 7.2, 7.3, 7.4, 8, 9, 10, 11, 12, 13, 14. These include confidentiality and security obligations concerning the Licensed Source Code and other confidential information.\n\nYes, there are ongoing confidentiality obligations that survive termination. Specifically, the confidentiality obligations concerning the Licensed Source Code will survive for five (5) years after the disclosure of such information.',
#      'data_point_verbatim': '9.4 Survival. Articles 7.2, 7.3, 7.4, 8, 9, 10, 11, 12, 13, 14 shall survive any termination or expiration of this Agreement.'}]},
#   {'section_name': 'Confidentiality',
#    'section_description': 'Clauses that outline confidentiality obligations and exceptions for both parties.',
#    'data_points': [{'data_point_name': 'Confidentiality Obligations',
#      'data_point_description': 'Obligations related to the confidentiality of the contract and any information shared between parties.',
#      'data_point_questions': ['What are the confidentiality obligations for each party?',
#       'Are there any exceptions to these obligations?'],
#      'data_point_overview': 'The confidentiality obligations require each party to treat all Confidential Information of the other party as confidential and to use reasonable efforts not to disclose such information. Exceptions to these obligations include information that is publicly known, known to the receiving party prior to disclosure, or disclosed with written consent. Additionally, obligations to return Confidential Information upon termination of the Agreement are specified.',
#      'data_point_answers': 'Each party must treat as confidential all Confidential Information of the other party and must not use it except as allowed in the Agreement. They are required to notify the other party of any actual or suspected misuse or unauthorized disclosure of such Confidential Information.\n\nExceptions to these confidentiality obligations include information that was in the public domain at the time of disclosure or has entered the public domain through no fault of the receiving party, was known to the receiving party at the time of disclosure, was disclosed with prior written approval, was independently developed by the receiving party, or disclosed pursuant to a court order.',
#      'data_point_verbatim': "12.2 Confidentiality. Each party shall treat as confidential all Confidential Information of the other party, shall not use such Confidential Information except as set forth herein, and shall use reasonable efforts not to disclose such Confidential Information disclosed to it by the other party under this Agreement.\n\n12.3 Exception. Not withstanding the above, neither party shall have liability to the other party with regard to any Confidential Information of such other party which the receiving party can demonstrate:\n(i) was in the public domain at the time it was disclosed or has entered the public domain through no fault of the receiving party; (ii) was known to the receiving party, at the time of disclosure, as demonstrated by files in existence at the time of disclosure; (iii) was disclosed with the prior written approval of the disclosing party; (iv) was, is presently or may be in the future independently developed by the receiving party without any use of the Confidential Information of any other party, as demonstrated by files created at the time of such independent development; (v) became known to the receiving party, without restriction, from a source other than the disclosing party without breach of this Agreement by the receiving party and otherwise not in violation of the disclosing party's rights; (vi) has been disclosed to third parties by the disclosing party without restrictions similar to those contained in this Agreement; or (vii) is disclosed pursuant to the order or requirement of a court, administrative agency, or other governmental body; provided, however, that the receiving party shall provide prompt written notice thereof to the disclosing party to enable the disclosing party to seek a protective order or otherwise prevent or restrict such disclosure."},
#     {'data_point_name': 'Confidential Information Definition',
#      'data_point_description': 'How confidential information is defined within the contract.',
#      'data_point_questions': ["How does the contract define 'Confidential Information'?",
#       'What types of information are considered confidential under the contract?'],
#      'data_point_overview': 'Confidential Information is defined as any information disclosed by one party to the other that is marked as confidential or proprietary, or designated as confidential at the time of oral disclosure and later reduced to writing. This definition includes all information shared during the course of the Agreement.',
#      'data_point_answers': "The contract defines 'Confidential Information' as any information disclosed by one party to another pursuant to this Agreement which is marked as confidential or proprietary, or, if disclosed orally, is designated as confidential at the time of disclosure and is subsequently reduced to a writing which is marked as confidential or proprietary and provided to the receiving party within thirty (30) days after such oral disclosure.\n\nTypes of information considered confidential include any proprietary information that is marked as such, as well as any information designated as confidential during oral communication that is later documented appropriately.",
#      'data_point_verbatim': "12.1 Confidential Information. As used in this Agreement, the term 'Confidential Information' shall mean any information disclosed by one party to another pursuant to this Agreement which is marked as confidential or proprietary, or, if disclosed orally, is designated as confidential at the time of disclosure and is subsequently reduced to a writing which is marked as confidential or proprietary and is provided to the receiving party within thirty (30) days after such oral disclosure."}]}]}

# %%
gpt_executor.plan

# %% [markdown]
# ## Run MetaMesh for Single Contract

# %%
from src.metamesh import MetaMesh
contract_path = '/Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt'

# %%
metamesh = MetaMesh(
    planner_model='o1-preview',
    executor_model='gpt-4o',
    planner_temp=0.01,
    executor_temp=0.01,
    debug=True
)

# %%
contract_plan = metamesh.process_contract(contract_path)
# Out:
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt
#
# Generating Plan:
#
# System Prompt:
# # Role
# You are the **Planner Agent.** Your primary responsibility is to create a comprehensive **structured representation template** for a given contract document, which will be used to collect data points from the contract. Alongside the structured representation template, you will also develop detailed instructions for agents that will be created to collect the required data points to populate the template.
#
# The end objective is to enable answering a set of yes/no questions that test a deep understanding of the contract’s clauses, terms, and implications. These questions cover various aspects of the contract such as Non-Compete clauses, No Solicitation, Revenue/Profit Sharing, Price Restrictions, Minimum Commitments, Volume Restrictions, Most Favored Nation clauses, Intellectual Property (IP) Ownership Assignment, Uncapped Liability, Cap on Liability, Liquidated Damages, etc. , and your structured representation template should be designed to capture all necessary information to accurately answer these questions.
#
# Your structured representation template and agent execution plan should be designed with this objective in mind, ensuring that all necessary information is collected to accurately answer these questions.
#
# The structured representation template will guide agents on what information to extract from the contract, ensuring that all relevant details are captured efficiently. This template should be optimally designed to encompass all critical information from the contract, enabling lawyers to understand the contract fully, interpret its clauses, and answer any questions pertaining to it. The structured representation should be self-contained and include all necessary information for a complete understanding of the contract.
#
# # Your Tasks:
#
# 1. **Analyze the Contract Document**:
#     - Carefully read and understand the given contract document.
#     - Identify all key elements, clauses, terms, parties involved, obligations, rights, and any other significant components.
#     - Keep in mind the end objective of enabling accurate answers to yes/no questions that test understanding of the contract.
#
# 2. **Identify the relevant information to collect**:
#     - Determine all the information needed to fully comprehend the contract and to answer any potential yes/no questions about it.
#     - Think about what details are necessary to definitively answer questions about the presence, terms, and implications of various contract clauses.
#     - Consider any nuances or specific conditions that could affect the answers.
#
# 3. **Design the Structured Representation Template**:
#     - **Structure and Organization**:  Decide on the best way to organize the information logically and coherently, with a focus on capturing data required to answer any yes/no questions about the contract.
#     - **Sections and Data Points**: Break down the template into sections, each containing relevant data points that collectively represent a comprehensive understanding of the contract.
#     - **Detailing Data Points**:
#         - **Data Point Name**: Provide a concise and descriptive name for each data point.
#         - **Data Point Description**: Explain what the data point represents and what it covers.
#         - **Data Point Questions**: List specific questions that will guide agents in extracting the data point from the contract.
#         - **Data Point Instructions**: Give clear instructions on how agents should collect the data point, including any formatting guidelines or considerations.
#     - **Sections Details**:
#         - **Section Name**: Assign a clear and descriptive name to each section.
#         - **Section Description**: Proide an overview of what the section covers.
#         - **Data Points**: List the data points that will be collected in the section.
#         - **Section Agent**:
#           - **Agent Name**: Provide a unique name to the agent, related to the type of expert they are.
#           - **Agent Instructions**: Provide detailed instructions outlining the agent’s role, responsibilities, and the approach they should take to collect the data points. Include:
#             - Description of the agent’s role (persona) and responsibilities.
#             - Information about the specific section of the template and the data points that the agent is expected to collect.
#             - Instructions on what the information is about and how to best collect it.
#             - A concise thought process for the agent to use when collecting the data points, and any other relevant information.
# 4. **Introduction and Template Notes**:
#     - **Introduction**: Provide a brief introduction to the template and its purpose.
#     - **Template Notes**: Include any additional information or special considerations for the template.
#
#
# # Instructions for Each Key in the Output JSON
#
# **Plan**:
#
#     - **introduction**: A brief explanation of the purpose of the template and instructions on how to use it.
#     - **sections**: An array of sections, each containing:
#         - **section_name**: The name of the section (e.g., “Parties Involved”, “Payment Terms”).
#         - **section_description**: A description of what the section covers.
#         - **data_points**: An array of data points within the section.
#         - **section_agent**: The agent responsible for collecting data points for the section and the instructions for the agent.
#
# **data_points (within each section)**:
#     - **data_point_name**: The name of the data point.
#     - **data_point_description**: A detailed description of the data point.
#     - **data_point_questions**: A list of specific questions to guide agents in extracting the data point.
#     - **data_point_instructions**: Instructions on how to collect the data point, including any formatting or content guidelines.
#
# **section_agent(within each section)**:
#     - **agent_name**: The name of the agent.
#     - **agent_instructions**: Detailed instructions for the agent, including their role, the section they are responsible for, information about the data points and how to collect them, the thought process the agent should follow, and any other relevant information.
#
# # Important Notes:
# - Ensure that all fields are filled accurately and completely.
# - Focus on collecting information that will enable accurate answers to any yes/no questions that test understanding of the contract.
# - Follow the specified structure strictly and ensure consistency in the output.
# - Do not include any explanations or text outside the JSON object.
# - Only output the expected JSON object which contains the structured representation template with sections and their corresponding agents.
# - Make sure to include detailed instructions for each agent.
#
#
# # Output Format
#
# ```json
#
# {
#   "$defs": {
#     "AgentInfo": {
#       "properties": {
#         "agent_name": {
#           "description": "The name of the agent that will collect data points for a section.",
#           "title": "Agent Name",
#           "type": "string"
#         },
#         "agent_instructions": {
#           "description": "Detailed instructions for the agent on how to collect data points for a section. This should include the agent's role, the section it is collecting data points for, information about the data points and how to collect them, the thought process the agent should follow, and any other relevant information.",
#           "title": "Agent Instructions",
#           "type": "string"
#         }
#       },
#       "required": [
#         "agent_name",
#         "agent_instructions"
#       ],
#       "title": "AgentInfo",
#       "type": "object"
#     },
#     "DataPoint": {
#       "properties": {
#         "data_point_name": {
#           "description": "The name of the data point that the agent will collect.",
#           "title": "Data Point Name",
#           "type": "string"
#         },
#         "data_point_description": {
#           "description": "A description of the data point for the agent so it knows what information to collect for the data point.",
#           "title": "Data Point Description",
#           "type": "string"
#         },
#         "data_point_questions": {
#           "description": "A list of questions that will help guide agents when collecting information about the data point.",
#           "items": {
#             "type": "string"
#           },
#           "title": "Data Point Questions",
#           "type": "array"
#         },
#         "data_point_instructions": {
#           "description": "Instructions for the agent on how to collect the data point.",
#           "title": "Data Point Instructions",
#           "type": "string"
#         }
#       },
#       "required": [
#         "data_point_name",
#         "data_point_description",
#         "data_point_questions",
#         "data_point_instructions"
#       ],
#       "title": "DataPoint",
#       "type": "object"
#     },
#     "TemplateSection": {
#       "properties": {
#         "section_name": {
#           "description": "The name of the section that the agent will collect data points for.",
#           "title": "Section Name",
#           "type": "string"
#         },
#         "section_description": {
#           "description": "A description of the section for the agent so it knows what information is expected to be collected in the section.",
#           "title": "Section Description",
#           "type": "string"
#         },
#         "data_points": {
#           "description": "A list of data points that the agent will collect for the section.",
#           "items": {
#             "$ref": "#/$defs/DataPoint"
#           },
#           "title": "Data Points",
#           "type": "array"
#         },
#         "section_agent": {
#           "$ref": "#/$defs/AgentInfo",
#           "description": "The agents that will collect data points for the section."
#         }
#       },
#       "required": [
#         "section_name",
#         "section_description",
#         "data_points",
#         "section_agent"
#       ],
#       "title": "TemplateSection",
#       "type": "object"
#     }
#   },
#   "properties": {
#     "introduction": {
#       "description": "The introduction to the template that the agent will use to understand the overall structure of the template.",
#       "title": "Introduction",
#       "type": "string"
#     },
#     "sections": {
#       "description": "A list of sections and the agents that will collect data points for the sections.",
#       "items": {
#         "$ref": "#/$defs/TemplateSection"
#       },
#       "title": "Sections",
#       "type": "array"
#     }
#   },
#   "required": [
#     "introduction",
#     "sections"
#   ],
#   "title": "Plan",
#   "type": "object"
# }
#
# ```
#
#
# # Example
#
# Following is an example of how the response should look like:
#
# ```json
# {
#   "introduction": "This template serves as a comprehensive guide for extracting all essential information from the contract to enable a deep understanding of its clauses and terms. Agents should use this template to collect data systematically, ensuring that all relevant aspects are covered to facilitate accurate analysis and decision-making.",
#   "sections": [
#     {
#       "section_name": "Non-Compete Clause",
#       "section_description": "Information related to any non-compete clauses within the contract.",
#       "data_points": [
#         {
#           "data_point_name": "Existence of Non-Compete Clause",
#           "data_point_description": "Indicates whether a non-compete clause exists in the contract.",
#           "data_point_questions": [
#             "Does the contract contain a non-compete clause?"
#           ],
#           "data_point_instructions": "Review the entire contract to identify any clauses that restrict a party from engaging in competing business activities. Note the presence or absence of such clauses."
#         },
#         {
#           "data_point_name": "Non-Compete Scope",
#           "data_point_description": "Details about the scope of the non-compete clause, including restricted activities.",
#           "data_point_questions": [
#             "What specific activities are restricted under the non-compete clause?"
#           ],
#           "data_point_instructions": "Extract and list all activities that are prohibited for the restricted party according to the non-compete clause."
#         },
#         {
#           "data_point_name": "Non-Compete Duration",
#           "data_point_description": "The time period during which the non-compete clause is effective.",
#           "data_point_questions": [
#             "What is the duration of the non-compete clause?"
#           ],
#           "data_point_instructions": "Identify the start and end dates of the non-compete restrictions, or the conditions that determine its duration."
#         },
#         {
#           "data_point_name": "Non-Compete Geographic Limitations",
#           "data_point_description": "Geographical areas where the non-compete clause applies.",
#           "data_point_questions": [
#             "What geographic areas are covered by the non-compete clause?"
#           ],
#           "data_point_instructions": "Extract any specified regions, countries, or territories where the non-compete restrictions are in effect."
#         }
#       ],
#       "section_agent": {
#         "agent_name": "NonCompeteAgent",
#         "agent_instructions": "As the NonCompeteAgent, your role is to identify and extract all information related to non-compete clauses within the contract. Focus on determining whether such a clause exists and, if so, detailing its scope, duration, and geographic limitations. Carefully analyze the language used to understand any exceptions or special conditions. Use precise language and cite the relevant sections of the contract."
#       }
#     },
#     {
#       "section_name": "No Solicitation",
#       "section_description": "Information regarding any no-solicitation clauses that prevent parties from soliciting employees or clients.",
#       "data_points": [
#         {
#           "data_point_name": "Existence of No-Solicitation Clause",
#           "data_point_description": "Indicates whether the contract includes a no-solicitation clause.",
#           "data_point_questions": [
#             "Does the contract contain a no-solicitation clause?"
#           ],
#           "data_point_instructions": "Examine the contract to identify any clauses that restrict a party from soliciting employees, customers, or clients of the other party."
#         },
#         {
#           "data_point_name": "No-Solicitation Scope",
#           "data_point_description": "Details about the scope of the no-solicitation clause.",
#           "data_point_questions": [
#             "Which parties or individuals are protected under the no-solicitation clause?",
#             "What activities are restricted by the no-solicitation clause?"
#           ],
#           "data_point_instructions": "Extract information about who cannot be solicited (e.g., employees, clients) and what types of solicitation are prohibited."
#         },
#         {
#           "data_point_name": "No-Solicitation Duration",
#           "data_point_description": "The time period during which the no-solicitation clause is effective.",
#           "data_point_questions": [
#             "What is the duration of the no-solicitation clause?"
#           ],
#           "data_point_instructions": "Identify the time frame during which the no-solicitation restrictions apply."
#         }
#       ],
#       "section_agent": {
#         "agent_name": "NoSolicitationAgent",
#         "agent_instructions": "As the NoSolicitationAgent, your responsibility is to find and detail any no-solicitation clauses within the contract. Pay attention to whom the restrictions apply, what activities are prohibited, and the duration of the restrictions. Be thorough in capturing all relevant details to ensure a complete understanding of the clause."
#       }
#     },
#     {
#       "section_name": "Intellectual Property Rights",
#       "section_description": "Information regarding ownership and assignment of intellectual property (IP) created under the contract.",
#       "data_points": [
#         {
#           "data_point_name": "IP Ownership Assignment",
#           "data_point_description": "Determines whether intellectual property rights are assigned to a party.",
#           "data_point_questions": [
#             "Does the contract include an assignment of intellectual property rights?",
#             "Which party retains ownership of the IP created under the contract?"
#           ],
#           "data_point_instructions": "Identify clauses that specify the ownership of IP resulting from the contract. Note which party is assigned the rights and under what conditions."
#         },
#         {
#           "data_point_name": "License Grants",
#           "data_point_description": "Details of any licenses granted for the use of existing IP.",
#           "data_point_questions": [
#             "Does the contract grant licenses to use existing IP?",
#             "What are the terms and limitations of the license grants?"
#           ],
#           "data_point_instructions": "Extract information about any licenses provided, including scope, duration, and any restrictions or royalties involved."
#         }
#       ],
#       "section_agent": {
#         "agent_name": "IPAgent",
#         "agent_instructions": "As the IPAgent, your task is to extract all clauses related to intellectual property rights. Focus on ownership assignments, license grants, and any restrictions on IP use. Ensure that you understand and accurately capture the terms, including any conditions or limitations. Provide clear summaries and reference specific contract sections."
#       }
#     },
#     {
#       "section_name": "Liability and Indemnification",
#       "section_description": "Clauses outlining limitations of liability and indemnification obligations between parties.",
#       "data_points": [
#         {
#           "data_point_name": "Limitation of Liability",
#           "data_point_description": "Whether the contract includes limitations on liability and the extent of those limitations.",
#           "data_point_questions": [
#             "Does the contract limit the liability of any party?",
#             "What is the cap on liability, if any?",
#             "Are there exclusions for certain types of damages?"
#           ],
#           "data_point_instructions": "Identify any clauses that limit the amount or types of damages recoverable. Note the specific limits and any exclusions."
#         },
#         {
#           "data_point_name": "Uncapped Liability",
#           "data_point_description": "Whether any liabilities are explicitly stated as uncapped.",
#           "data_point_questions": [
#             "Are there any liabilities that are uncapped for specific breaches?"
#           ],
#           "data_point_instructions": "Look for clauses that state unlimited liability for certain breaches, such as confidentiality breaches or willful misconduct."
#         },
#         {
#           "data_point_name": "Indemnification Obligations",
#           "data_point_description": "Details of any indemnification responsibilities one party has towards another.",
#           "data_point_questions": [
#             "Does the contract include indemnification clauses?",
#             "What events trigger indemnification obligations?",
#             "What are the scope and limitations of the indemnification?"
#           ],
#           "data_point_instructions": "Extract clauses that require a party to compensate the other for certain losses or damages, specifying the conditions and extent."
#         }
#       ],
#       "section_agent": {
#         "agent_name": "LiabilityAgent",
#         "agent_instructions": "Your role as the LiabilityAgent is to thoroughly analyze the contract for any provisions related to liability limitations and indemnification. Carefully document the specifics, including any caps on liability and the circumstances under which indemnification is required. Be meticulous in noting any exceptions or special conditions."
#       }
#     },
#     {
#       "section_name": "Termination Conditions",
#       "section_description": "Conditions under which the contract can be terminated by either party.",
#       "data_points": [
#         {
#           "data_point_name": "Termination Rights",
#           "data_point_description": "The rights of each party to terminate the contract and under what circumstances.",
#           "data_point_questions": [
#             "Under what conditions can the contract be terminated?",
#             "Is there a required notice period prior to termination?",
#             "Are there any penalties or fees associated with termination?"
#           ],
#           "data_point_instructions": "Identify and summarize the termination clauses, including permissible reasons for termination, notice requirements, and any financial implications."
#         },
#         {
#           "data_point_name": "Post-Termination Obligations",
#           "data_point_description": "Obligations that survive the termination of the contract.",
#           "data_point_questions": [
#             "What obligations continue after termination?",
#             "Are there any ongoing confidentiality or non-compete obligations?"
#           ],
#           "data_point_instructions": "Detail any responsibilities that persist beyond the contract's termination, highlighting their duration and scope."
#         },
#         {
#           "data_point_name": "Liquidated Damages",
#           "data_point_description": "Whether the contract contains clauses for predetermined damages or termination fees.",
#           "data_point_questions": [
#             "Does the contract specify liquidated damages or termination fees?",
#             "What are the amounts and conditions for these damages?"
#           ],
#           "data_point_instructions": "Extract any clauses that outline specific monetary penalties associated with termination or breach."
#         }
#       ],
#       "section_agent": {
#         "agent_name": "TerminationAgent",
#         "agent_instructions": "As the TerminationAgent, you are to extract all information related to how and when the contract can be terminated. Pay close attention to required procedures, notice periods, any penalties or fees, and obligations that survive termination. Ensure that you capture all nuances to provide a complete picture."
#       }
#     }
#     // Include additional sections as needed
#   ]
# }
#
# ```
#
# User Prompt:
#
#             Please analyze the following contract and perform the tasks as per your instructions.
#
#             ## Contract Document
#
#             1                                                                    EXHIBIT 10.3
#
#                 SOFTWARE LICENSE AND MAINTENANCE AGREEMENT
#
#       This Software license and maintenance agreement ("Agreement") is entered into effective as of August 4, 1997 (the "Effective Date") by and between D2 Technologies, Inc., a California corporation with offices at 104 West Anapamu Street, Santa Barbara, CA 93101 ("D2"), and Summa Four Inc., a Delaware corporation with offices at 25 Sundial Avenue, Manchester, New Hampshire 03103-7251 ("LICENSEE").
#
#       WHEREAS, D2 has previously developed certain software and designs capable of performing certain voice processing functions;
#
#       WHEREAS, LICENSEE is developing a product which requires certain software functions and designs capable of performing certain voice processing functions;
#
#       WHEREAS, D2 desires to license to LICENSEE certain of its software technology for use in connection with Licensee's products:
#
#       WHEREAS, D2 is further willing to provide certain maintenance and support services to LICENSEE in relation to such software technology;
#
#       NOW THEREFORE, in consideration of the mutual promises and covenants contained herein, the parties agree as follows:
#
# 1.       DEFINITIONS
#
#       1.1      "Licensed Technology" shall mean software licensed to LICENSEE by D2 as listed in Exhibit A.
#
#       1.2      "DSP" shall mean digital signal processing.
#
#       1.3      "Runtime License Fee" shall have the meaning set forth in Article 2.2(iii).
#
#       1.4      "Specifications" shall mean D2's specifications of the Licensed Technology which are attached hereto as Exhibit A.
#
#       1.5      "Update" shall mean a new release of a software product which typically includes bug fixes and/or minor feature changes, but does not include substantial new functionality.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
#   2
#
#       1.6      "New Version" in this Agreement shall mean a new release of Licensed Technology that provides significant performance enhancements, including new releases of software product optimized for different members of the same DSP processor family which is based on the same core architecture and instruction set.
#
#       1.7      "Defect" shall mean any failure of Licensed Technology to meet the Specification as a result of a material failure (including an error or "bug" that is material) of the Licensed Technology. "Material" is defined as priority A, B, and C in Article 6.3.
#
#       1.8      "Source Code" shall mean all computer programming instructions relating to a software product in a form readable by humans and typically prepared by a programmer. Source Code includes associated procedural code, comments, utilities, tools, notes, data diagrams and related and supporting technical documentation.
#
#       1.9      "Object Code" shall mean software code resulting from the translation or processing of Source Code by a computer into machine language or intermediate code, which thus is in a form that would not be convenient to human understanding of the program logic, but which is appropriate for execution or interpretation by a computer.
#
#       1.10     "Licensed Source Code" shall mean Source Code for Licensed Technology.
#
#       1.11     "Licensee Product" shall mean the product being developed by LICENSEE as described in Exhibit B, which utilizes Licensed Technology. LICENSEE shall own all rights, title and interest in Licensee Product. D2 shall have no rights to Licensee Product.
#
#       1.12     "End User" shall mean a person or business entity that purchases, leases or otherwise properly obtains the right to use or distribute a Licensee Product directly from LICENSEE or through one or more intermediaries.
#
# 2.       LICENSED TECHNOLOGY
#
#       2.1      Ownership. Subject to the rights granted to LICENSEE in this Agreement, D2 owns all right, title and interest in and to the Licensed Technology. Notwithstanding the foregoing, LICENSEE shall retain all right, title and interest in and to modifications to the Licensed Source Code made by LICENSEE pursuant to the license in Article 2.2 below, subject always to D2's ownership rights in the underlying Licensed Technology.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
# 3
#
#
#
#
#
#       2.2      License to LICENSEE.
#
#                         (i)      Subject to the terms and conditions of this  Agreement, D2 hereby grants LICENSEE a perpetual non-exclusive, worldwide license, to use Licensed Technology in Object Code format only as an incorporated part of the Licensee Product. For this purpose, LICENSEE may also modify, create derivative works, of and reproduce and have reproduced the Licensed Technology, and to develop, use, market and distribute (directly or through third parties) Licensed Technology, or modifications or derivative works of the Licensed Technology created by or for LICENSEE.
#
#                         (ii)     In consideration for the right to modify, develop and completely own derivative works of the Licensed Technology set forth in Article 2.2 (i) above, LICENSEE shall pay D2 a license fee (the "Development License Fee") as set forth in Exhibit C. Final acceptance testing shall be completed by the parties according to Article 4 of this Agreement.
#
#                         (iii)    LICENSEE shall pay D2 a license fee  ("Runtime License Fee") as set forth in Exhibit C for each copy of the Licensed Technology that LICENSEE distributes to end users directly or through third parties for such end-user's use in connection with Licensee's Product. The Runtime License Fee shall be paid by LICENSEE quarterly for Licensee Products which have been paid for by Licensee's end-user customer in the prior quarter. To the extent Licensee accepts returns or is required to provide refunds to its customers (and to the extent additional Licensee Products are delivered to customers for warranty or maintenance/support purposes), such circumstances will either entitle Licensee to obtain a credit against future Runtime License Fees owed or, in the case of warranty/maintenance or support deliveries, no Runtime License Fees shall be due at all.
#
#                         (iv)     LICENSEE is also granted a limited  non-transferable non-exclusive license to Licensed Source Code to perform software maintenance functions according the terms set forth in Article 7 of this Agreement.
#
#                         (v)      D2 shall provide LICENSEE with master copies of the Licensed Technology, in Source Code and Object Code format, promptly after such software has been completed, tested and approved for release by D2 and Licensee. In any event, D2 shall deliver all Licensed Technology completely tested and approved for performance in accordance with the specifications.
#
#       2.3      End User License. LICENSEE shall ensure that all Licensed Technology distributed by LICENSEE shall be subject to a shrink-wrap agreement or other end user agreement which contains a provision substantially similar to the provision set forth in Exhibit D.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
# 4
#
# 3.       ADDITIONAL TECHNOLOGY LICENSE
#
#       3.1      New Functions. In the event that LICENSEE requires any additional functionality or technology substantially different from those set forth in Exhibit A or otherwise made available by D2 to other Licensees, D2 shall license such additional functionality or technology to LICENSEE at D2's then best price to its other Licensees. Such additional technology licenses shall be subject to the same terms of this agreement except for an amendment to the product specification and price schedule of Exhibits A and C. Any other new licensing terms shall be negotiated in advance and included in said amendment.
#
#       3.2      Different Processors.
#
#                (A)      "Supported Processors": If D2 offers or plans to offer all or part of Licensed Technology on a processor ("Supported Processor") different from the Texas Instruments (TI) TMS320C54x family of processors, D2 shall make available to LICENSEE such new versions of Licensed Technology under the same terms of this Agreement subject to the license fees as follows:
#
#                         (i)      The development license fees for any part or all of Licensed Technology for each "Supported Processor" shall be 50% of that for the TMS320C54x processor family as listed in Exhibit C.
#
#                         (ii)     The per-processor runtime license fees for any "Supported Processor" shall be the same as that specified in Exhibit C for the TI TMS320C54x.
#
#                         (iii)    The runtime license fee CAP in exhibit C shall be cumulative across the TI TMS320C54x, TMS32OC55x, TMS330C6x, and other TI processors based on the same core processor architecture. For processors other than the TI processors listed in this Article 3.2A(iii) ("additional supported processors"), the runtime license fee CAP and buy-out license fee in Exhibit C shall be increased by 25% for each "additional supported processor." The CAP for Licensed Technology shall be cumulative across all "Supported Processors" (including "additional supported processors") utilized by LICENSEE. If the cumulative inflation index (according to government published Consumer Price Index) exceeds 25% from the effective date of this Agreement to the time when D2 makes available Licensed Technology for an "additional supported processor", D2 and LICENSEE agree to negotiate in good faith reasonable incremental runtime license fees for Licensed Technology used in such "additional supported processor.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
# 5
#
#                (B) "Unsupported Processors". If LICENSEE requires versions of Licensed Technology on a processor other than the "Supported Processors", D2 agrees to negotiate in good faith with LICENSEE an agreement to develop such a version of Licensed Technology. Such an agreement shall include appropriate development license fees and runtime license fees as well as special engineering
#
#
#
#
#
# service fees.
#
# 4.       ACCEPTANCE
#
#       Upon delivery of the Licensed Technology to Licensee, D2 will have tested and verified that such Licensed Technology shall perform in accordance with an acceptance specification agreed to by D2 and LICENSEE. The acceptance specification shall be completed no later than 90 days after the effective date of this Agreement and shall be attached to this agreement as Exhibit F. Upon successful completion of the acceptance testing, LICENSEE shall make the final "Development License Fee" payment described in Exhibit C LICENSEE shall, within thirty (30) days after delivery of any Licensed Technology, either accept such Licensed Technology or reject such Licensed Technology because of nonconformance with the Specifications. LICENSEE shall provide D2 with written notification of any rejection of Licensed Technology which explains the basis for such rejection. If completion of testing is precluded or delayed due to performance deficiencies, incompatibilities or other Defects in the Licensed Technology, D2 shall immediately and without any additional payment, correct such Defects.. All corrected versions of the Licensed Technology shall be subject to the acceptance procedures set forth above in this Article 4.
#
# 5.       REPORTS, AUDITS
#
#       5.1      Reports. Within thirty days after the end of each calendar quarter during the term of this Agreement, LICENSEE shall provide D2 with written reports setting forth the number of LICENSEE Products containing the Licensed Technology that were licensed to end users by LICENSEE in such calendar quarter as more particularly described in Article 2.2 (iii) above.
#
#       5.2      Audits. LICENSEE shall maintain records of its distribution of Licensee Products containing the Licensed Technology, for a period of one year after the date on which LICENSEE distributes the Products to which such records pertain. D2 may audit such records by engaging an independent public audit firm, approved in advance by Licensee, upon thirty days written notice, provided that (i) no more than one such audit may be made in any twelve month period, (ii) D2 may only audit LICENSEE's records for a particular time period once, and (iii) D2 shall be responsible for ensuring that the auditor executes and abides by LICENSEE's confidentiality agreement.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
# 6
#
# 6.       MAINTENANCE AND SUPPORT
#
#       6.1      Maintenance and Support Obligation, Fees. On the date of expiry of the Warranty period defined in Article 8.3, and on any anniversary of the expiry date, LICENSEE may in its sole discretion pay D2 a "Maintenance and Support Fee" according to Exhibit C. In return for payment of such fee, D2 shall provide LICENSEE with the maintenance and support set forth in this Article 6 for a period of twelve months (the "Contract Year"). In any event, D2 shall provide support and maintenance services to Licensee during the Warranty period in breadth and scope which is no less than the support and maintenance services described in this Article. D2 shall make available to LICENSEE the maintenance and support services according to the terms of this Article 6 for a minimum of five years after Acceptance of Licensed Technology.
#
#       6.2      Maintenance. Maintenance to be provided by D2 to LICENSEE shall include without limitation the following services;
#
#                         (i)      D2 shall update and maintain the Licensed Technology throughout the term of this Agreement. It is intended that D2 shall release at least 1 Update or New Version release during each 12 month calendar year. Upon the releases of any Update or New Version of the Licensed Technology (including manuals), D2 shall promptly notify and deliver to LICENSEE such Update or New Version.
#
#                         (ii)     D2 will initially deliver to LICENSEE one  (1) copy of any Updates or New Versions to the Licensed Technology and one (1) set of corresponding manuals for each copy of the Licensed Technology for which LICENSEE has paid the appropriate development license fees and maintenance fees pursuant to Exhibit C as soon as such Updates or New Versions and corresponding manuals become available and shall maintain such Updates or New Versions throughout this agreement.
#
#       6.3      Error Correction. If D2 becomes aware of any Defect in the Licensed Technology, D2 shall promptly provide LICENSEE with written notice of such Defect. D2 shall have no obligation to actively monitor the Licensed Technology for Defects after such software has been accepted by LICENSEE. D2 shall work diligently to promptly correct Defects in accordance with the following schedule; "days" shall mean calendar days.
#
#       ERROR PRIORITY (1)         RESPONSE (2)      CLOSURE (3)
#
#       Emergency (A)              24 hours          7 days
#
#       Critical (B)               2 days            14 days
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
# 7
#
#       Non-Critical (C)           30 days           Next Update                                                       or                                                       New Version
#
#                (1)      Priority:
#
#                         -A-      Catastrophic product or module Defects that do not have a viable detour or work around available.
#
#
#
#
#
#                         -B-      Defects  that have been  substantiated  as a serious inconvenience to LICENSEE or an End User. This includes any priority A Defect for which a viable detour or work around is available.
#
#                         -C-      All other problems that LICENSEE and an End User can easily avoid for which there is no urgency for a resolution.
#
#                (2)      Response: Response consists of providing, as appropriate, one of the following to the LICENSEE: an existing correction; A new correction; a viable detour or work around; a request for more information to complete analysis of the problem, or a plan on how the problem will be corrected.
#
#                (3)      Closure: Closure consists of providing a final  correction or work around of the problem including an Update and revised or new Documentation as necessary.
#
#       If D2 fails to correct Defects according to the schedule specified in this Article 6, LICENSEE shall deduct from future runtime license fees, as specified in Exhibit C, a "late fee" for each day past the deadline in the schedule of this section. The "late fee" shall equal to 50% (fifty percent) of the runtime license fees paid to D2 for the previous two calendar quarters equally divided over 180 (one hundred eighty) days. In the event LICENSEE has selected the Buy-out option in the runtime license fee schedule of Exhibit C, then the "late fee" for each day past the deadline shall be 50% (fifty percent) of the Buy-out fee equally divided over 1095 (one thousand and ninety five) days; and this "late fee" shall be paid to LICENSEE each calendar month until the error is corrected either by D2 or LICENSEE.
#
#       6.4      Support. D2 will provide the following support to LICENSEE throughout the Warranty period and for those subsequent years for which support has been purchased by Licensee:
#
#                         (i)      D2 will assist LICENSEE in determining if problems encountered by LICENSEE are caused by programming errors in the Licensed Technology.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL    8
#
#                         (ii)     D2 will answer questions concerning the installation of Licensed Technology.
#
#                         (iii)    D2 will assist LICENSEE in resolving LICENSEE's problems, if any, arising from the normal usage of the Licensed Technology.
#
#                         (iv)     D2 shall appoint a qualified technical staff as the "Technical Contact" to co-ordinate all support and maintenance services. The "Technical Contact" shall be available to LICENSEE during D2's normal business hours; in the event that appointed "Technical Contact" is not available, a back-up "Technical Contact" shall be temporarily assigned and LICENSEE shall be notified.
#
#       6.5      Notification and Cooperation by LICENSEE. To obtain support from D2 under this Article 6, LICENSEE shall provide D2 with written notice which will contain a description of the problem for which LICENSEE is seeking support. D2 shall have no obligation to correct problems which are due to modifications to Licensed Technology performed by LICENSEE; provided, that if D2 agrees to correct such problems it shall charge its then current time and materials rates, which shall be payable by LICENSEE within thirty days after invoicing by D2. LICENSEE agrees to provide D2 with access to LICENSEE's equipment and computer systems on a temporary basis and as needed to allow D2 to reproduce, correct and verify the correction of the problem reported by LICENSEE or otherwise identified by D2.
#
# 7.       LIMITED SOURCE CODE LICENSE AND PROTECTION
#
#       7.1      Source Code delivery. D2 shall, after acceptance of Licensed Technology by LICENSEE and within fifteen days after receiving such a request from LICENSEE deliver a copy of the fully commented Source Code for the then current version of the Licensed Technology and information needed for compiling and building the Licensed Technology Object Code to LICENSEE. Thereafter, D2 shall automatically deliver a copy of the fully commented Licensed Source Code for the then current version of the Licensed Technology within fifteen days after the release of any Updates or New Versions of the Licensed Technology.
#
#       7.2      Source Code Access Conditions. The following events shall constitute "Source Code Access Conditions": (i) D2's insolvency, general assignment for the benefit of creditors, or ceasing to do business, or (ii) D2's failure or inability to meet its warranty, maintenance and support obligations under Article 6, or its warranty obligations under Article 8.3, within fifteen days after written notice by LICENSEE to D2 of D2's failure to meet such obligations, or (iii) termination of this Agreement by LICENSEE pursuant to Articles 9.3 and 9.4, or (iv) as needed by LICENSEE for fault isolation.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL    9
#
#       7.3      Use of Licensed Source Code. After "Source Code Access Conditions" is met, LICENSEE shall have the right to use, modify, reproduce and have reproduced Object Code from Licensed Source Code to develop, use, market, distribute, and to maintain and support the Licensed Technology in the Licensee Product. LICENSEE shall not have any right to develop new DSP technology or derivative DSP technology with the Licensed Source Code.
#
#       7.4      Confidentiality and security.
#
#                (A)      General. LICENSEE acknowledges and agrees that the Licensed Source Code constitutes the confidential and proprietary trade secrets of D2, and that LICENSEE's protection thereof is essential to this Agreement and
#
#
#
#
#
# a condition of LICENSEE's use and possession of the Licensed Source Code. LICENSEE shall retain in strict confidence any and all elements of the Licensed Source Code and use the Licensed Source Code only as expressly licensed herein. LICENSEE agrees that it will under no circumstances distribute or in any way disseminate or disclose the Licensed Source Code to third parties, except as expressly provided in this Article 7. LICENSEE shall be relieved of this obligation of confidentiality to the extent that such information was in the public domain at the time it was disclosed or has become in the public domain through no fault of LICENSEE.
#
#                (B)      Security. LICENSEE agrees to use the Licensed Source Code under carefully controlled conditions for the purposes set forth in this Agreement, and to inform all employees who are given access to the Licensed Source Code by LICENSEE that such materials are confidential trade secrets of D2 and are licensed to LICENSEE as such. LICENSEE shall restrict access to the Licensed Source Code to those employees and Contractors of LICENSEE who have agreed to be bound by a confidentiality obligation which incorporates the protections and restrictions substantially as set forth herein, and who have a need to know in order to carry out the purposes of this Agreement. D2 shall be made a third party beneficiary of any such agreements, and shall have the right to directly enforce the terms of those agreements, and of this Agreement, insofar as such enforcement relates to the Licensed Source Code.
#
#                (C)      LICENSEE agrees to notify D2 promptly in the event of any breach of its security under conditions in which it would appear that the Licensed Source Code were prejudiced or exposed to loss. LICENSEE shall, upon request of D2, take all other reasonable steps necessary to recover any compromised trade secrets disclosed to or placed in the possession of LICENSEE by virtue of this Agreement. The cost of taking such steps shall be borne solely by LICENSEE.
#
# Software License                                           D2 Technologies, Inc. and Maintenance Agreement       August 4, 1997                      CONFIDENTIAL
#
# 10
#
#                (D)      Remedies. LICENSEE acknowledges that any breach of any of its obligations under this Article 7 is likely to cause or threaten irreparable harm to D2, and accordingly, LICENSEE agrees that in such event, D2 shall be entitled to equitable relief to protect its interest therein, including but not limited to preliminary and permanent injunctive relief, as well as money damages.
#
#                (E)      Hardware.
#
#                         (i)      Two (2) computers, as identified in Exhibit E, may be used as the Development Computer and Back-up Computer. The Back-up Computer may be used as the Development Computer during any time when the Development Computer is inoperative because it is malfunctioning or undergoing repair, maintenance or other modification.
#
#                         (ii)     LICENSEE may at any time notify D2 in writing of any changes, such as replacements or additions, that LICENSEE wishes to make to Development and Back-up Computers for specific Licensed Source Code. D2 will prepare an amended Exhibit E as required to cover such changes, and such changes shall become effective after execution of the amended Exhibit E by LICENSEE.
#
# ...
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# data_points=[DataPoint(data_point_name='Maintenance and Support Obligations', data_point_description='Services that D2 is obligated to provide to Licensee.', data_point_questions=['What maintenance and support services is D2 required to provide?'], data_point_overview='D2 is obligated to provide maintenance and support services to the Licensee, which include updating and maintaining the Licensed Technology, releasing at least one Update or New Version each year, and delivering these updates to the Licensee. D2 is also required to assist the Licensee in determining problems, answering installation questions, and resolving issues arising from the normal usage of the Licensed Technology. Additionally, D2 must appoint a Technical Contact to coordinate support and maintenance services.', data_point_answers='D2 is required to update and maintain the Licensed Technology throughout the term of the Agreement, releasing at least one Update or New Version each year. Upon the release of any Update or New Version, D2 must promptly notify and deliver these to the Licensee. D2 must also assist the Licensee in determining if problems are caused by programming errors, answer installation questions, and resolve issues from normal usage. Furthermore, D2 must appoint a Technical Contact to coordinate all support and maintenance services.', data_point_verbatim='6.2 Maintenance. Maintenance to be provided by D2 to LICENSEE shall include without limitation the following services; (i) D2 shall update and maintain the Licensed Technology throughout the term of this Agreement. It is intended that D2 shall release at least 1 Update or New Version release during each 12 month calendar year. Upon the releases of any Update or New Version of the Licensed Technology (including manuals), D2 shall promptly notify and deliver to LICENSEE such Update or New Version. (ii) D2 will initially deliver to LICENSEE one (1) copy of any Updates or New Versions to the Licensed Technology and one (1) set of corresponding manuals for each copy of the Licensed Technology for which LICENSEE has paid the appropriate development license fees and maintenance fees pursuant to Exhibit C as soon as such Updates or New Versions and corresponding manuals become available and shall maintain such Updates or New Versions throughout this agreement.'), DataPoint(data_point_name='Maintenance Fees', data_point_description='Fees associated with maintenance and support services.', data_point_questions=['What are the fees for maintenance and support?', 'When do these fees apply?'], data_point_overview='The maintenance fee for the Licensed Technology is $20,000 per year after the expiry of the Warranty period. This fee is renewable at the end of each Contract Year. If the Licensee completes payments of $100,000 in Runtime License Fees during the Contract Year, D2 will apply a credit equal to 100% of the Maintenance Fee against the Runtime License Fees. If the Licensee exercises the Buy Out option for Runtime License Fees, there will be no Maintenance Fee for the first three years after the Warranty period.', data_point_answers='The maintenance fee for the Licensed Technology is $20,000 per year after the expiry of the Warranty period. This fee is renewable at the end of each Contract Year. \n\nThe maintenance fees apply starting from the date after the Warranty period and are renewable at the end of each Contract Year. If the Licensee completes payments of $100,000 in Runtime License Fees during the Contract Year, D2 will apply a credit equal to 100% of the Maintenance Fee against the Runtime License Fees. If the Licensee exercises the Buy Out option for Runtime License Fees, there will be no Maintenance Fee for the first three years after the Warranty period.', data_point_verbatim='MAINTENANCE FEES: LICENSED TECHNOLOGY FOR THE BASIC SERVICES SPECIFIED IN EXHIBIT A\n\nThe Maintenance Fee after the expiry of the Warranty period shall be $20,000 per year, starting from the date after the Warrant ...
# Processing section: Liquidated Damages
#
# Agent: LiquidatedDamagesAgent
#
# System Prompt:
# # Agent Role
#             You are LiquidatedDamagesAgent. Your role is to extract information for the section 'Liquidated Damages' of the contract.
#
#             # Agent Instructions
#             As the LiquidatedDamagesAgent, your role is to determine whether the contract includes any liquidated damages provisions. Carefully read the agreement to identify any clauses that specify predetermined damages in case of breach or termination. Note the presence or absence of such clauses.
#
#             # Section Description
#
#             Information about any clauses that specify predetermined damages in case of breach or termination.
#
#             # Data Points to Extract
#
#                 ## Data Point Name: Existence of Liquidated Damages Clause
#                 - Description: Determines whether the contract includes any liquidated damages provisions.
#                 - Questions: Does the contract include any clauses specifying liquidated damages?
#                 - Instructions: Review the agreement to identify any clauses that stipulate predetermined damages in the event of breach or termination.
#
#
#             # Additional Important Instructions:
#
#             - Carefully read the contract provided in the user prompt.
#             - Sequentially process each data point listed above.
#             - For each data point, provide the following information:
#             - **data_point_name**: Copy verbatim from the data point name provided.
#             - **data_point_description**: Copy verbatim from the data point description provided.
#             - **data_point_questions**: Copy verbatim from the data point questions provided.
#             - **data_point_overview**: Summarize all the information collected for the data point.
#             - **data_point_answers**: Answer each of the data point questions in separate paragraphs.
#             - **data_point_verbatim**: Provide the exact text from the contract that was used to collect the data point.
#
#             - Provide the extracted data points in the following JSON format:
#
#             {
#                 "data_points": [
#                     {
#                         "data_point_name": "...",
#                         "data_point_description": "...",
#                         "data_point_questions": ["...", "..."],
#                         "data_point_overview": "...",
#                         "data_point_answers": "...",
#                         "data_point_verbatim": "..."
#                     }
#                     // Include additional data points as needed
#                 ]
#             }
#
#             # Output Format
#             ```json
#                             {
#                 "$defs": {
#                     "DataPoint": {
#                     "properties": {
#                         "data_point_name": {
#                         "description": "The name of the data point for which the agent collected the information. Should be copied verbatim from the data point name in the plan.",
#                         "title": "Data Point Name",
#                         "type": "string"
#                         },
#                         "data_point_description": {
#                         "description": "A description of what is contained in the data point. Should be copied verbatim from the data point description in the plan.",
#                         "title": "Data Point Description",
#                         "type": "string"
#                         },
#                         "data_point_questions": {
#                         "description": "A list of questions that the agent used to collect the data point. Should be copied verbatim from the data point questions in the plan.",
#                         "items": {
#                             "type": "string"
#                         },
#                         "title": "Data Point Questions",
#                         "type": "array"
#                         },
#                         "data_point_overview": {
#                         "description": "A summary of all the information that was collected for the datapoint by the agent.",
#                         "title": "Data Point Overview",
#                         "type": "string"
#                         },
#                         "data_point_answers": {
#                         "description": "The answer to the data point questions. The agent should include all the answers for the data point questions in the data point answers. Write each answer in a new paragraph.",
#                         "title": "Data Point Answers",
#                         "type": "string"
#                         },
#                         "data_point_verbatim": {
#                         "description": "The verbatim text from the contract that the agent used to collect the data point. Should be copied verbatim from the contract.",
#                         "title": "Data Point Verbatim",
#                         "type": "string"
#                         }
#                     },
#                     "required": [
#                         "data_point_name",
#                         "data_point_description",
#                         "data_point_questions",
#                         "data_point_overview",
#                         "data_point_answers",
#                         "data_point_verbatim"
#                     ],
#                     "title": "DataPoint",
#                     "type": "object"
#                     }
#                 },
#                 "properties": {
#                     "data_points": {
#                     "description": "A list of data points that were extracted from the contract by the agent.",
#                     "items": {
#                         "$ref": "#/$defs/DataPoint"
#                     },
#                     "title": "Data Points",
#                     "type": "array"
#                     }
#                 },
#                 "required": [
#                     "data_points"
#                 ],
#                 "title": "ExtractedData",
#                 "type": "object"
#                 }
#
#             ```
#
#             - Ensure that your response is valid JSON and follows the structure exactly.
#             - Do not include any text outside the JSON object.
#
# Agent Response:
# data_points=[DataPoint(data_point_name='Existence of Liquidated Damages Clause', data_point_description='Determines whether the contract includes any liquidated damages provisions.', data_point_questions=['Does the contract include any clauses specifying liquidated damages?'], data_point_overview="The contract includes a provision for liquidated damages in the form of a 'late fee' for failure to correct defects according to a specified schedule. This fee is calculated based on the runtime license fees paid in the previous two calendar quarters or the Buy-out fee, depending on the option selected by the Licensee.", data_point_answers="Yes, the contract includes a clause specifying liquidated damages. The clause is found in Article 6.3, which outlines a 'late fee' as a form of liquidated damages for failure to correct defects according to the specified schedule. This fee is calculated as 50% of the runtime license fees paid in the previous two calendar quarters, divided over 180 days, or 50% of the Buy-out fee divided over 1095 days, depending on the option selected by the Licensee.", data_point_verbatim="If D2 fails to correct Defects according to the schedule specified in this Article 6, LICENSEE shall deduct from future runtime license fees, as specified in Exhibit C, a 'late fee' for each day past the deadline in the schedule of this section. The 'late fee' shall equal to 50% (fifty percent) of the runtime license fees paid to D2 for the previous two calendar quarters equally divided over 180 (one hundred eighty) days. In the event LICENSEE has selected the Buy-out option in the runtime license fee schedule of Exhibit C, then the 'late fee' for each day past the deadline shall be 50% (fifty percent) of the Buy-out fee equally divided over 1095 (one thousand and ninety five) days; and this 'late fee' shall be paid to LICENSEE each calendar month until the error is corrected either by D2 or LICENSEE.")]
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o_20241214_131001/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o_20241214_131001/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o_20241214_131001/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_processing_times.json

# %% [markdown]
# ## Run MetaMesh for Dataset

# %%
from src.metamesh import MetaMesh
metamesh = MetaMesh(
    planner_model='o1-preview',
    executor_model='gpt-4o-mini',
    planner_temp=0.01,
    executor_temp=0.01,
    debug=False
)

# %%
cuad_subset_path = 'data/processed/cuad_subset_performance_set.json'
metamesh.process_dataset(cuad_subset_path, run_parallel=True)
# Out:
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT.txt
# Generating plan...
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement.txt
# Generating plan...
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement.txt
# Processing section: Parties and Agreement Overview
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1)_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1)_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).txt
# Processing section: Parties Involved
# Processing section: Grant of License
# Processing section: Non-Compete Clause
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT.txt
# Processing section: Exclusivity Obligations
# Processing section: Payment Terms
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement.txt
# Processing section: Parties Involved
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT.txt
# Processing section: Intellectual Property Rights
# Processing section: No Solicitation Clause
# Processing section: Grant of License
# Processing section: Revenue and Profit Sharing
# Processing section: Term and Renewal Provisions
# Processing section: Intellectual Property Rights
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement.txt
# Processing section: Term and Termination
# Processing section: Payment and Revenue Sharing
# Processing section: Intellectual Property Rights
# Processing section: Confidentiality and Use of Name
# Processing section: Limitation of Liability
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement.txt
# Processing section: Non-Compete Clause
# Processing section: Liability and Indemnification
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement.txt
# Processing section: Non-Compete and Exclusivity
# Processing section: Exclusivity and Non-Compete Clauses
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement.txt
# Processing section: Parties Involved
# Processing section: Indemnification
# Processing section: Price Restrictions
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT.txt
# Processing section: Parties Involved
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT.txt
# Processing section: Non-Compete Clause
# Processing section: Contract Period and Territory
# Processing section: Non-Compete Clause
# Processing section: Term and Termination
# Processing section: Non-Compete Clause
# Processing section: Revenue and Financial Terms
# Processing section: Termination Conditions
# Processing section: Minimum Commitments
# Processing section: No-Solicitation Clause
# Processing section: Grant of Rights and Exclusivity
# Processing section: No Solicitation Clause
# Processing section: Intellectual Property Rights and Ownership
# Processing section: No-Solicitation Clause
# Processing section: Confidentiality
# Processing section: Assignment and Sublicensing
# Processing section: Obligations of the Company
# Processing section: Volume Restrictions
# Processing section: Revenue and Profit Sharing
# Processing section: Intellectual Property Rights
# Processing section: Governing Law and Dispute Resolution
# Processing section: No-Solicitation Clause
# Processing section: Intellectual Property Rights
# Processing section: Intellectual Property Rights
# Processing section: Revenue and Profit Sharing
# Processing section: Remuneration and Payment Terms
# Processing section: Other Key Clauses
# Processing section: Most Favored Nation Clause
# Processing section: Payment Terms and Revenue Sharing
# Processing section: Liability and Indemnification
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement.txt
# Generating plan...
# Processing section: Intellectual Property (IP) Ownership Assignment
# Processing section: Assignment
# Processing section: Limitation of Liability and Indemnification
# Processing section: Liability and Indemnification
# Processing section: Minimum Commitments
# Processing section: Intellectual Property Rights
# Processing section: Intellectual Property Rights and Trademarks
# Processing section: Termination Conditions
# Processing section: Termination Conditions
# Processing section: Governing Law and Venue
# Processing section: Intellectual Property Rights
# Processing section: Liability and Indemnification
# Processing section: Limitation of Liability
# Processing section: Warranties
# Processing section: Liability and Indemnification
# Processing section: Liability and Indemnification
# Processing section: Termination Conditions
# Processing section: Confidentiality Obligations
# Processing section: Liquidated Damages
# Processing section: Indemnification
# Processing section: Liability and Indemnification
# Processing section: Confidentiality Obligations
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/SUMMAFOURINC_06_19_1998-EX-10.3-SOFTWARE LICENSE AND MAINTENANCE AGREEMENT_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT.txt
# Generating plan...
# Processing section: Termination Conditions
# Processing section: Termination Conditions
# Processing section: Confidentiality
# Processing section: Confidentiality
# Processing section: Assignment and Subcontracting
# Processing section: Term and Termination
# Processing section: Branding and Trademark Usage
# Processing section: Confidentiality Obligations
# Processing section: Dispute Resolution and Governing Law
# Processing section: Governing Law
# Processing section: Confidentiality
# Processing section: Limitation of Liability and Indemnification
# Processing section: Termination Conditions
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement.txt
# Generating plan...
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement.txt
# Generating plan...
# Processing section: Year 2000 Compliance
# Processing section: Dispute Resolution
# Processing section: Dispute Resolution
# Processing section: Personal Appearances and Marketing Support
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT.txt
# Generating plan...
# Processing section: Force Majeure
# Processing section: Governing Law and Jurisdiction
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT.txt
# Generating plan...
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/N2KINC_10_16_1997-EX-10.16-SPONSORSHIP AGREEMENT_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement.txt
# Generating plan...
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1)_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1)_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1)_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT.txt
# Generating plan...
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement_processing_times.json
# Processing document: /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT.txt
# Successfully loaded content from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT.txt
# Generating plan...
# Processing section: Confidentiality Obligations
# Processing section: Termination Conditions
# Processing section: Dispute Resolution and Governing Law
# Processing section: Assignment and Transfer
# Processing section: Diligence and Performance Obligations
# Processing section: Payment Terms
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement.txt
# Processing section: Parties Involved
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement.txt
# Processing section: Non-Compete Clause
# Processing section: Appointment and Exclusivity
# Processing section: No Solicitation
# Processing section: Intellectual Property Rights
# Processing section: No Solicitation
# Processing section: Pricing and Payment Terms
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement_processing_times.json
# Processing section: Minimum Commitments and Volume Restrictions
# Processing section: Most Favored Nation Clause
# Processing section: Liability and Indemnification
# Processing section: Intellectual Property Rights
# Processing section: Most Favored Nation Clause
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT.txt
# Processing section: Parties Involved
# Processing section: Confidentiality and Trade Secrets
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement_processing_times.json
# Processing section: Termination Conditions
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement.txt
# Processing section: Parties Involved
# Processing section: Non-Compete Clause
# Processing section: Limitation of Liability
# Processing section: Non-Compete Clause
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement.txt
# Processing section: Non-Compete Clause
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT.txt
# Processing section: Parties Involved
# Processing section: No Solicitation Clause
# Processing section: No Solicitation
# Processing section: Warranties
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT.txt
# Processing section: Parties Involved
# Processing section: Confidentiality
# Processing section: Purpose and Scope of Agreement
# Processing section: Revenue and Profit Sharing
# Processing section: License Grant and Territory
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT.txt
# Processing section: Parties Involved
# Processing section: Term and Termination
# Processing section: Revenue and Profit Sharing
# Processing section: Intellectual Property Rights
# Processing section: Non-Compete Clause
# Processing section: Compliance and Legal Requirements
# Processing section: Price Restrictions
# Processing section: Funding and Payment Terms
# Processing section: License Terms
# Processing section: Confidentiality and Intellectual Property Rights
# Processing section: Liquidated Damages
# Processing section: Minimum Commitments
# Processing section: Dispute Resolution and Governing Law
# Processing section: Revenue and Profit Sharing
# Processing section: Intellectual Property Rights and Inventions
# Processing section: Force Majeure
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement_processing_times.json
# Processing section: Volume Restrictions
# Processing section: Price Restrictions
# Processing section: Payment Terms
# Processing section: Most Favored Nation Clause
# Processing section: Limitations of Liability and Indemnification
# Processing section: Minimum Commitments and Volume Restrictions
# Processing section: Confidentiality Obligations
# Processing section: Intellectual Property Rights
# Processing section: Royalties and Commissions
# Processing section: Minimum Commitments
# Processing section: Payment Terms and Pricing
# Plan saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT_plan.json
# Loaded plan from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/plans/o1-preview_gpt-4o-mini_20241214_133053/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT_plan.json
# Loaded contract from /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/data/raw/full_contract_txt/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT.txt
# Processing section: Non-Compete and No-Solicitation Clauses
# Processing section: Intellectual Property Rights
# Processing section: Most Favored Nation Clause
# Processing section: Limitation of Liability
# Processing section: Dispute Resolution
# Processing section: Intellectual Property Rights
# Processing section: Liability and Indemnification
# Processing section: Liability and Indemnification
# Processing section: Intellectual Property Rights
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement_processing_times.json
# Processing section: Term and Termination
# Processing section: Liability and Indemnification
# Processing section: Liquidated Damages
# Processing section: No-Solicitation Clause
# Processing section: Termination Conditions
# Processing section: Assignment and Subcontracting
# Processing section: Termination Conditions
# Processing section: Liability and Indemnification
# Processing section: Price Restrictions
# Processing section: Governing Law and Dispute Resolution
# Processing section: Miscellaneous Provisions
# Processing section: Liability and Indemnification
# Processing section: Term and Termination Conditions
# Processing section: Volume Restrictions
# Processing section: Confidentiality Obligations
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/HYPERIONSOFTWARECORP_09_28_1994-EX-10.47-EXCLUSIVE DISTRIBUTOR AGREEMENT_processing_times.json
# Processing section: Liquidated Damages
# Processing section: Confidentiality
# Processing section: Publication Rights
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement_processing_times.json
# Processing section: Liquidated Damages
# Processing section: Non-Compete and No-Solicitation
# Processing section: Escrow Arrangements
# Processing section: Termination Conditions
# Processing section: Term and Termination Conditions
# Processing section: Compliance and Regulatory Obligations
# Processing section: Governing Law and Dispute Resolution
# Processing section: Maintenance Obligations
# Processing section: Assignment and Subcontracting
# Processing section: Assignment
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT_processing_times.json
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/MACROGENICSINC_08_02_2013-EX-10-COLLABORATION AGREEMENT_processing_times.json
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement_processing_times.json
# Processing section: Dispute Resolution
# Processing section: Most Favored Nation Clause
# Processing section: Force Majeure
# Processing section: Assignment
# Processing section: Minimum Commitments and Volume Restrictions
# Processing section: Insurance Requirements
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/TELKOMSALTD_01_30_2003-EX-10-LICENCE AND MAINTENANCE AGREEMENT_processing_times.json
# Processing section: Price Restrictions and Adjustments
# Processing section: Revenue and Profit Sharing
# Processing section: Volume Flexibility and Supply Commitments
# Results saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/reps/o1-preview_gpt-4o-mini_20241214_133053/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT_extraction.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT_token_counts.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/MANUFACTURERSSERVICESLTD_06_05_2000-EX-10.14-OUTSOURCING AGREEMENT_processing_times.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/time/o1-preview_gpt-4o-mini_20241214_133053/average_time_calculations.json
# Metrics saved to /Users/tawab/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/results/token_counts/o1-preview_gpt-4o-mini_20241214_133053/average_token_counts.json

# %%
from multiprocessing import Pool, cpu_count
print(cpu_count())
# Out:
# 12
