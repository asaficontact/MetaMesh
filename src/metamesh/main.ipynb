# %%
# Add the parent directory to the system path
import sys
import os
parent_dir = os.path.dirname(os.getcwd())  
sys.path.append(parent_dir)

from metamesh.explorer import Explorer
from metamesh.roles import Manager
# Out:
# 2024-12-10 00:05:48.507 | INFO     | metamesh.system.config:__init__:43 - Config loading done.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:1227, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1226 try:
# -> 1227     evaluated_type = _typing_extra.eval_type(field_info.annotation, *self._types_namespace)
#    1228 except NameError as e:
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_typing_extra.py:577, in eval_type(value, globalns, localns)
#     576 value = _type_convert(value)
# --> 577 return eval_type_backport(value, globalns, localns)
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_typing_extra.py:609, in eval_type_backport(value, globalns, localns, type_params)
#     608 try:
# --> 609     return _eval_type_backport(value, globalns, localns, type_params)
#     610 except TypeError as e:
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_typing_extra.py:633, in _eval_type_backport(value, globalns, localns, type_params)
#     632 try:
# --> 633     return _eval_type(value, globalns, localns, type_params)
#     634 except TypeError as e:
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_typing_extra.py:667, in _eval_type(value, globalns, localns, type_params)
#     666 else:
# --> 667     return typing._eval_type(  # type: ignore
#     668         value, globalns, localns
#     669     )
#
# File ~/miniconda3/envs/metamask/lib/python3.11/typing.py:395, in _eval_type(t, globalns, localns, recursive_guard)
#     394 if isinstance(t, ForwardRef):
# --> 395     return t._evaluate(globalns, localns, recursive_guard)
#     396 if isinstance(t, (_GenericAlias, GenericAlias, types.UnionType)):
#
# File ~/miniconda3/envs/metamask/lib/python3.11/typing.py:910, in ForwardRef._evaluate(self, globalns, localns, recursive_guard)
#     904 type_ = _type_check(
#     905     eval(self.__forward_code__, globalns, localns),
#     906     "Forward references must evaluate to types.",
#     907     is_argument=self.__forward_is_argument__,
#     908     allow_special_forms=self.__forward_is_class__,
#     909 )
# --> 910 self.__forward_value__ = _eval_type(
#     911     type_, globalns, localns, recursive_guard | {self.__forward_arg__}
#     912 )
#     913 self.__forward_evaluated__ = True
#
# File ~/miniconda3/envs/metamask/lib/python3.11/typing.py:395, in _eval_type(t, globalns, localns, recursive_guard)
#     394 if isinstance(t, ForwardRef):
# --> 395     return t._evaluate(globalns, localns, recursive_guard)
#     396 if isinstance(t, (_GenericAlias, GenericAlias, types.UnionType)):
#
# File ~/miniconda3/envs/metamask/lib/python3.11/typing.py:905, in ForwardRef._evaluate(self, globalns, localns, recursive_guard)
#     901     globalns = getattr(
#     902         sys.modules.get(self.__forward_module__, None), '__dict__', globalns
#     903     )
#     904 type_ = _type_check(
# --> 905     eval(self.__forward_code__, globalns, localns),
#     906     "Forward references must evaluate to types.",
#     907     is_argument=self.__forward_is_argument__,
#     908     allow_special_forms=self.__forward_is_class__,
#     909 )
#     910 self.__forward_value__ = _eval_type(
#     911     type_, globalns, localns, recursive_guard | {self.__forward_arg__}
#     912 )
#
# File <string>:1
#
# NameError: name 'Environment' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PydanticUndefinedAnnotation               Traceback (most recent call last)
# Cell In[1], line 7
#       4 parent_dir = os.path.dirname(os.getcwd())
#       5 sys.path.append(parent_dir)
# ----> 7 from metamesh.explorer import Explorer
#       8 from metamesh.roles import Manager
#
# File ~/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/src/metamesh/explorer.py:9
#       3 """
#       4 @Author  : tawabsafi
#       5 @Modified From    : https://github.com/Link-AGI/AutoAgents/blob/main/autoagents/explorer.py
#       6 """
#       7 from pydantic import BaseModel, Field
# ----> 9 from .roles import Role
#      10 from .actions import Requirement
#      11 from .environment import Environment
#
# File ~/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/src/metamesh/roles/__init__.py:4
#       1 #!/usr/bin/env python
#       2 # -*- coding: utf-8 -*-
# ----> 4 from .role import Role
#       5 from .manager import Manager
#       6 from .observer import ObserverAgents, ObserverPlans
#
# File ~/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/src/metamesh/roles/role.py:90
#      85     @property
#      86     def history(self) -> list[Message]:
#      87         return self.memory.get()
# ---> 90 class Role:
#      91     """Role/Agent"""
#      93     def __init__(self, name="", profile="", goal="", constraints="", desc="", proxy="", llm_api_key="", serpapi_api_key=""):
#
# File ~/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/src/metamesh/roles/role.py:247, in Role()
#     243     await self._publish_message(rsp)
#     244     return rsp
# --> 247 RoleContext.model_rebuild()
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/main.py:594, in BaseModel.model_rebuild(cls, force, raise_errors, _parent_namespace_depth, _types_namespace)
#     592 # manually override defer_build so complete_model_class doesn't skip building the model again
#     593 config = {**cls.model_config, 'defer_build': False}
# --> 594 return _model_construction.complete_model_class(
#     595     cls,
#     596     cls.__name__,
#     597     _config.ConfigWrapper(config, check=False),
#     598     raise_errors=raise_errors,
#     599     ns_resolver=ns_resolver,
#     600 )
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py:658, in complete_model_class(cls, cls_name, config_wrapper, raise_errors, ns_resolver, create_model_module)
#     651 handler = CallbackGetCoreSchemaHandler(
#     652     partial(gen_schema.generate_schema, from_dunder_get_core_schema=False),
#     653     gen_schema,
#     654     ref_mode='unpack',
#     655 )
#     657 try:
# --> 658     schema = cls.__get_pydantic_core_schema__(cls, handler)
#     659 except PydanticUndefinedAnnotation as e:
#     660     if raise_errors:
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/main.py:702, in BaseModel.__get_pydantic_core_schema__(cls, source, handler)
#     699     if not cls.__pydantic_generic_metadata__['origin']:
#     700         return cls.__pydantic_core_schema__
# --> 702 return handler(source)
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_schema_generation_shared.py:84, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      83 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 84     schema = self._handler(source_type)
#      85     ref = schema.get('ref')
#      86     if self._ref_mode == 'to-def':
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:612, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     609         schema = from_property
#     611 if schema is None:
# --> 612     schema = self._generate_schema_inner(obj)
#     614 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     615 if metadata_js_function is not None:
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:881, in GenerateSchema._generate_schema_inner(self, obj)
#     879 if lenient_issubclass(obj, BaseModel):
#     880     with self.model_type_stack.push(obj):
# --> 881         return self._model_schema(obj)
#     883 if isinstance(obj, PydanticRecursiveRef):
#     884     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:693, in GenerateSchema._model_schema(self, cls)
#     681     model_schema = core_schema.model_schema(
#     682         cls,
#     683         inner_schema,
#    (...)
#     689         ref=model_ref,
#     690     )
#     691 else:
#     692     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 693         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     694         computed_fields=[
#     695             self._computed_field_schema(d, decorators.field_serializers)
#     696             for d in computed_fields.values()
#     697         ],
#     698         extras_schema=extras_schema,
#     699         model_name=cls.__name__,
#     700     )
#     701     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     702     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:693, in <dictcomp>(.0)
#     681     model_schema = core_schema.model_schema(
#     682         cls,
#     683         inner_schema,
#    (...)
#     689         ref=model_ref,
#     690     )
#     691 else:
#     692     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 693         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     694         computed_fields=[
#     695             self._computed_field_schema(d, decorators.field_serializers)
#     696             for d in computed_fields.values()
#     697         ],
#     698         extras_schema=extras_schema,
#     699         model_name=cls.__name__,
#     700     )
#     701     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     702     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:1073, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1066 def _generate_md_field_schema(
#    1067     self,
#    1068     name: str,
#    1069     field_info: FieldInfo,
#    1070     decorators: DecoratorInfos,
#    1071 ) -> core_schema.ModelField:
#    1072     """Prepare a ModelField to represent a model field."""
# -> 1073     common_field = self._common_field_schema(name, field_info, decorators)
#    1074     return core_schema.model_field(
#    1075         common_field['schema'],
#    1076         serialization_exclude=common_field['serialization_exclude'],
#    (...)
#    1080         metadata=common_field['metadata'],
#    1081     )
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:1229, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1227     evaluated_type = _typing_extra.eval_type(field_info.annotation, *self._types_namespace)
#    1228 except NameError as e:
# -> 1229     raise PydanticUndefinedAnnotation.from_name_error(e) from e
#    1230 evaluated_type = replace_types(evaluated_type, self._typevars_map)
#    1231 field_info.evaluated = True
#
# PydanticUndefinedAnnotation: name 'Environment' is not defined
#
# For further information visit https://errors.pydantic.dev/2.10/u/undefined-annotation

# %%
explorer = Explorer(investment=2)

# %%
manager = Manager()
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 manager = Manager()
#
# File ~/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/src/metamesh/roles/manager.py:20, in Manager.__init__(self, name, profile, goal, constraints, serpapi_key, **kwargs)
#      18 def __init__(self, name="Ethan", profile="Manager", goal="Efficiently to finish the tasks or solve the problem",
#      19              constraints="", serpapi_key=None, **kwargs):
# ---> 20     super().__init__(name, profile, goal, constraints, **kwargs)
#      21     self._init_actions([CreateRoles, CheckRoles, CheckPlans])
#      22     self._watch([Requirement])
#
# File ~/Desktop/columbia/Courses/Fall2024/Practical Deep Learning Systems/Project/MetaMesh/src/metamesh/roles/role.py:100, in Role.__init__(self, name, profile, goal, constraints, desc, proxy, llm_api_key, serpapi_api_key)
#      98 self.init_actions = None
#      99 self._role_id = str(self._setting)
# --> 100 self._rc = RoleContext()
#     101 self._proxy = proxy
#     102 self._llm_api_key = llm_api_key
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/metamask/lib/python3.11/site-packages/pydantic/_internal/_mock_val_ser.py:100, in MockValSer.__getattr__(self, item)
#      98 # raise an AttributeError if `item` doesn't exist
#      99 getattr(self._val_or_ser, item)
# --> 100 raise PydanticUserError(self._error_message, code=self._code)
#
# PydanticUserError: `RoleContext` is not fully defined; you should define `Environment`, then call `RoleContext.model_rebuild()`.
#
# For further information visit https://errors.pydantic.dev/2.10/u/class-not-fully-defined
